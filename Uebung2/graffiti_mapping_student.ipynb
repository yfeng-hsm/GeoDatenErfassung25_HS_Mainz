# %% [markdown]
# GeoDatenErfassung_HS_Mainz
# # Übung 2 – Graffiti Mapping in Mainz
# Prof. Dr. Yu Feng
#
# ---
#
# ## Überblick
#
# Diese Übung führt Sie durch einen kompletten Workflow zur Detektion und Kartierung von Graffiti anhand von Street‑View‑Bildern:
#
# - Street‑View‑Bilder (Mapillary) für ein Untersuchungsgebiet abrufen
# - Bilder lokal zwischenspeichern und per YOLOv5 (Kommandozeile) auf Graffiti detektieren
# - Ergebnisse als thematisierte Geodaten auf einer interaktiven Karte visualisieren
#
# ---
#
# ## Lernziele
#
# - Arbeiten mit Koordinatenreferenzsystemen (ETRS89 / UTM Zone 32N, EPSG:25832)
# - Nutzung der Mapillary Graph API zur Datenakquise
# - CLI‑basierte Inferenz mit YOLOv5 und Auswertung der Textausgaben (labels/*.txt)
# - Kartographische Visualisierung (folium) mit inhaltlich codierten Markern und Popups
#
# ---
#
# ## Voraussetzungen
#
# - Gültiges Mapillary API‑Token (als Umgebungsvariable `MAPILLARY_TOKEN`)
# - Python‑Umgebung mit `requests`, `pyproj`, `folium`, `PIL` (Pillow); Internetzugang
# - Für die Detektion: `git` und `pip` verfügbar (zum Laden von `yolov5` und Abhängigkeiten)
# - YOLOv5‑Modell (Datei `model/best.pt` im Projektverzeichnis)
#
# ---
#
# ## Ablauf (Überblick)
#
# 1. **Untersuchungsgebiet festlegen**: Zentrum und BBox präzise in EPSG:25832 puffern und nach WGS84 zurückführen
# 2. **Bilder abrufen**: Mapillary Graph API nutzen, um alle Street‑View‑Bilder in der BBox zu laden
# 3. **Thumbnails speichern**: Bilder lokal im Ordner `images_dl/` ablegen
# 4. **Detektion ausführen**: YOLOv5 per Kommandozeile auf `images_dl/` laufen lassen; Ausgaben in `runs/graffiti_cli/exp/`
# 5. **Ergebnisse parsen**: `labels/*.txt` einlesen und in `has_graffiti` bzw. `results_by_id` strukturieren
# 6. **Assets vorbereiten**: Bilder komprimieren (geringere Dateigröße für HTML‑Export)
# 7. **Karte erstellen**: Interaktive Folium‑Karte mit farbcodierten Markern (Rot = Graffiti, Grün = sauber) und Popups mit annotierten Bildern
#
# ---
#
# ## Aufgaben (bearbeitbar/prüfbar)
#
# - **A1.** Variieren Sie den Suchradius (z. B. 100 m, 300 m, 500 m) und vergleichen Sie die Bildanzahl.
# - **A2.** Führen Sie die CLI‑Detektion aus und protokollieren Sie die Anzahl gefundener Graffiti‑Bilder.
# - **A3.** Passen Sie die Konfidenzschwelle (`--conf`) an (z. B. 0.15/0.25/0.35) und diskutieren Sie Präzision/Recall.
#
# ---
#
# ## Hinweise
#
# - **Ausgabeverzeichnisse**: Annotierte Bilder liegen nach der Detektion in `runs/graffiti_cli/exp/`; die Karte nutzt diese automatisch in den Popups.
# - **Leere Ergebnisse**: Falls keine Bilder gefunden werden, vergrößern Sie den Radius oder wechseln Sie an einen anderen Ort (z. B. Innenstadt, Bahnhofsbereich).

# %% [markdown]
# ## Schritt 0: Google Drive einbinden (nur für Google Colab)
#
# Wenn Sie dieses Notebook in Google Colab ausführen, wird hier Ihr Google Drive eingebunden. Dies ermöglicht den Zugriff auf das YOLOv5-Modell und weitere Projektdateien.

# %%
from google.colab import drive
drive.mount('/content/drive')

project_base_path = '/content/drive/MyDrive/Teaching_HS/P0002:1_Datenerfassung/github/GeoDatenErfassung25_HS_Mainz/Uebung2'
print(f"Project base path set to: {project_base_path}")
# Out:
# Mounted at /content/drive
# Project base path set to: /content/drive/MyDrive/Teaching_HS/P0002:1_Datenerfassung/github/GeoDatenErfassung25_HS_Mainz/Uebung2

# %% [markdown]
# ## Schritt 1: API-Token konfigurieren
#
# Mapillary benötigt ein gültiges Access Token. Sie können sich kostenlos bei [Mapillary](https://www.mapillary.com/developer) registrieren und ein Token generieren.

# %%
# -------------------------
# 0) Konfiguration: Mapillary Token aus Umgebungsvariable
# -------------------------
import os
import json
import math
import requests
from pyproj import Transformer

# Empfohlen: Umgebungsvariable setzen: export MAPILLARY_TOKEN="..."
# oder in Google Colab: userdata.get('MAPILLARY_TOKEN')

# TODO: Temporär im Code eintragen 
TOKEN = "PASTE_YOUR_MAPILLARY_TOKEN_HERE"  

if not TOKEN:
    raise RuntimeError("MAPILLARY_TOKEN fehlt. Bitte als Umgebungsvariable setzen oder temporär im Code eintragen.")

# %% [markdown]
# ## Schritt 2: Untersuchungsgebiet festlegen und BBox berechnen
#
# Das Untersuchungsgebiet wird durch einen Mittelpunkt (Lat/Lon) und einen Radius definiert. Die BoundingBox (BBox) wird präzise in EPSG:25832 (UTM Zone 32N) gepuffert, um gleichmäßige Abstände in Metern zu garantieren.

# %%
# -------------------------
# 1) Untersuchungsgebiet (Mainz Rheingauwall) + BBox in EPSG:25832
# -------------------------
# Zentrum des Untersuchungsgebiets (anpassbar)
center_lat = 50.012635951893
center_lon = 8.244556440625274

# Radius in Metern (z.B. 300/500/1000)
# Hinweis: Kleiner Radius = weniger Bilder, aber schneller; größerer Radius = mehr Bilder
radius_m = 10

transformer_to_utm = Transformer.from_crs("EPSG:4326", "EPSG:25832", always_xy=True)
transformer_to_wgs = Transformer.from_crs("EPSG:25832", "EPSG:4326", always_xy=True)

def bbox_from_center(lat, lon, radius_m):
    """
    TODO: Erzeugt eine BoundingBox (BBox) um einen Mittelpunkt.
    """

    return [west, south, east, north]

bbox = bbox_from_center(center_lat, center_lon, radius_m)
print("BBox [west, south, east, north]:", bbox)
print(f"Untersuchungsgebiet: Zentrum ({center_lat}, {center_lon}), Radius: {radius_m}m")
# Out:
# BBox [west, south, east, north]: [8.241736967458799, 50.01081909766579, 8.247375705467897, 50.01445274072047]
# Untersuchungsgebiet: Zentrum (50.012635951893, 8.244556440625274), Radius: 200m

# %% [markdown]
# ## Schritt 3: Street-View-Bilder von Mapillary abrufen
#
# Die Mapillary Graph API wird verwendet, um alle verfügbaren Street-View-Bilder innerhalb der BBox abzurufen. Die ersten 24 Bilder werden als Thumbnail-Galerie angezeigt.

# %%
# -------------------------
# 3) Bilder innerhalb der BBox abrufen und kurz anzeigen
# -------------------------
import requests
import time
from IPython.display import display, HTML

BASE = "https://graph.mapillary.com"
IMG_FIELDS = "id,thumb_1024_url,thumb_640_url,captured_at,geometry,compass_angle,computed_compass_angle"

def fetch_images_in_bbox(bbox, limit=None, per_page=1000, debug=False, sleep=0.05):
    """
    Ruft alle Mapillary-Bilder innerhalb der BBox ab.
    """
    west, south, east, north = bbox

    params = {
        "access_token": TOKEN,
        "bbox": f"{west},{south},{east},{north}",
        "fields": IMG_FIELDS,
        "limit": per_page,
        "image_type": "photo",
    }

    url = f"{BASE}/images"
    out = []
    page = 0

    while True:
        page += 1
        r = requests.get(url, params=params, timeout=60)
        if r.status_code != 200:
            raise RuntimeError(f"Mapillary API fehlgeschlagen: {r.status_code}\n{r.text}")

        data = r.json()
        items = data.get("data", []) or []
        out.extend(items)

        next_url = (data.get("paging") or {}).get("next")

        if debug:
            print(f"Seite {page}: {len(items)} Elemente | Gesamt {len(out)} | next={bool(next_url)}")

        # Begrenzen, falls limit gesetzt
        if limit is not None and len(out) >= limit:
            out = out[:limit]
            break

        # Ende, falls keine nächste Seite
        if not next_url:
            break

        # Nächste Seite: Graph API liefert vollständige URL; params leeren
        url = next_url
        params = None

        # Kurze Pause gegen Rate-Limits
        if sleep:
            time.sleep(sleep)

    return out

# Bilder abrufen
images = fetch_images_in_bbox(bbox, limit=None, debug=True)
print(f"\nBilder geladen: {len(images)}")

# Thumbnail-Galerie anzeigen (erste 24 Bilder)
thumb_blocks = []
for img in images[:24]:
    thumb = img.get("thumb_1024_url") or img.get("thumb_640_url")
    ts = img.get("captured_at") or ""
    if thumb:
        thumb_blocks.append(
            f'<div style="margin:6px;text-align:center;">'
            f'<img src="{thumb}" style="width:200px;border-radius:6px;">'
            f'<div style="font-size:12px;color:#555;">{ts}</div>'
            f"</div>"
        )

if thumb_blocks:
    gallery = "".join(thumb_blocks)
    display(HTML(f'<div style="display:flex;flex-wrap:wrap;">{gallery}</div>'))
else:
    print("Keine Thumbnails verfügbar.")
# Out:
# Seite 1: 729 Elemente | Gesamt 729 | next=False
#
# Bilder geladen: 729
# <div style="display:flex;flex-wrap:wrap;"><div style="margin:6px;text-align:center;"><img src="https://scontent-lax3-2.xx.fbcdn.net/m1/v/t6/An8OHeHEbMMdqp1Zdqjxq9HZ-GsGUJ1zpZ3A9gjIvpTXWbqXWm-h3iqKek7RyIm3kH7GCkFe6o5LDQBQukrz9IhMJEC2reBEI1b_SAQYx3XfXcR6IDNQOyqNQvBe_UnWi2TBi2ypzxT4QH32nAM4Vg?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=k230NPDDbSo_q_rDlov07w&_nc_oc=AdmUi4T1SlUWkcYL2fJ4LUUY2ng3cJvjAnAgYnr54_GXJzcic-pzL7SnSG8aKmasQZU&ccb=10-5&oh=00_AfrAZZJUwH4K8Z-S4NtfpT5yqnoM8hUzGBCvb6bfcyWcUg&oe=69879053&_nc_sid=201bca" style="width:200px;border-radius:6px;"><div style="font-size:12px;color:#555;">1496775817414</div></div><div style="margin:6px;text-align:center;"><img src="https://scontent-lax3-2.xx.fbcdn.net/m1/v/t6/An--OjzzKY9A-g64FREW7SIX9r6eHyHhAQN-ZWm3fkjWKjzqiM44dsy53CgFfrDG2PZ_64ODEbbJvFaKU58n9FoOl6wYd73wMR6cv9SVxB7Qs4Nh8g1p9qx_rvl0AC5arkPfwE-5DQjt9vGkq04ycQ?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=k230NPDDbSo_q_rDlov07w&_nc_oc=AdkP_g0nZ9O6kIBFmmCMtntCPM8XIKtO0SZdzCz-1fIBbXN2mzqZPUr1rdNgCLctGW4&ccb=10-5&oh=00_Afpb1-GEj7epq1kMvww7FJU40WEcU_OQlMJ4tOrydYUQyw&oe=6987809E&_nc_sid=201bca" style="width:200px;border-radius:6px;"><div style="font-size:12px;color:#555;">1429629507694</div></div><div style="margin:6px;text-align:center;"><img src="https://scontent-lax3-2.xx.fbcdn.net/m1/v/t6/An_2ipxV66NqI0ObGNJgl2VNQoD4p7ky92lANxSluWF-Fupe8o4sdKpyEbA5b9KmT1O1mUOqPTj3Z7jLCRdDDcUcbXGuVslRgnJf_7XIovilGon8xaVzYHuIliz2YWR-Jjq_8eo1HRGhGsH7DvXsTA?stp=s1024x764&edm=AOnQwmMEAAAA&_nc_gid=k230NPDDbSo_q_rDlov07w&_nc_oc=AdlV0an_v_AROlOPXYW5Jm15Nvj68eJ8mJ7PJ20FpR35GrMad0SsmqWjfqCHzneqr9I&ccb=10-5&oh=00_AfpWdh2QcXzWstIQ-31luRXS2YC4zfRVMBR0cBwk70qAuA&oe=69878522&_nc_sid=201bca" style="width:200px;border-radius:6px;"><div style="font-size:12px;color:#555;">1467819588832</div></div><div style="margin:6px;text-align:center;"><img src="https://scontent-lax3-2.xx.fbcdn.net/m1/v/t6/An9N_19TAvJm3JaKSJivG3h1KzpMwgZCNZsAQoK5MbcwFpC6GAIEfnXQDXlYTByaX0mxPXaj8sd7071S8PpLa2hmYjYepgjwfSF047VVSnlJcxv2atCYDZ823gxmT1p0aakz4_BaXC_QGXrkL61S7Q?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=k230NPDDbSo_q_rDlov07w&_nc_oc=AdlOv8XZCeGPfTIuD_NW6QguqVNId6KxwjGlPGZxcfscY7iUNe333I4pVdgSoYLivFU&ccb=10-5&oh=00_Afr8NbS68dGiigOthGcQEy1GkFfKBa3FwcuEkpE7mPDmVg&oe=69879CEA&_nc_sid=201bca" style="width:200px;border-radius:6px;"><div style="font-size:12px;color:#555;">1593339818302</div></div><div style="margin:6px;text-align:center;"><img src="https://scontent-lax3-2.xx.fbcdn.net/m1/v/t6/An8GDVYASuZqAP5reXmWKOxco0v_Q8kya57hL-JlgGdpHhsdm9cXK8_xGsueWFw-ty4ZaCJB3p-tEIcXFbnr2wPNU4Xf1VxZYJrgcpzqSYEn5_9-iqRv_SFQdzQqjGhOi3UhTvZhTkO56LGjorI5oA?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=k230NPDDbSo_q_rDlov07w&_nc_oc=AdmwDjiFqzoy69QSKd-mXvidcm7PiSP_Hm_w__EfieADF-JMyb6maaaShs7yzL9pm3w&ccb=10-5&oh=00_AfopYydojLq4BtGdlzk80dCG_kaiaArI1UL-T62PYbsg9A&oe=698772BA&_nc_sid=201bca" style="width:200px;border-radius:6px;"><div style="font-size:12px;color:#555;">1496775949799</div></div><div style="margin:6px;text-align:center;"><img src="https://scontent-lax3-2.xx.fbcdn.net/m1/v/t6/An-sNgxeoo0sMlZFfQ8YjJjHCm506UP58G-t6T10RI5Wt5cS1vVC1sZqWmZZBWyhPXvRyaeAkC8RhJ1hdu2biJb8ZkE5OMAJ-mNYfEPvaNB_F51XPxowxxHernuYPMgF6Qc37HHFp8tgWODou24FsoA?stp=s1024x764&edm=AOnQwmMEAAAA&_nc_gid=k230NPDDbSo_q_rDlov07w&_nc_oc=Adma-SjkNGtJG6S9j46iGRfhUDE2hy5jkoU5viuqUc6qHcEZCEPh-POnirnfJ83UkIQ&ccb=10-5&oh=00_AfolLnZUzacZyZhTmnl7eSVznsAEu0qoCk1wwuxjBogTnQ&oe=69877438&_nc_sid=201bca" style="width:200px;border-radius:6px;"><div style="font-size:12px;color:#555;">1446650460053</div></div><div style="margin:6px;text-align:center;"><img src="https://scontent-lax3-2.xx.fbcdn.net/m1/v/t6/An9hrW-r7bfvS08PdzLlcjBhC-kkd_gtEUYW-VMzS8gsF5-RdiLkroboIVazVVgwu2VAD5WXqj4lHxeijNSUELBe04XTsaoPU8woKAqUw7iuTgrXDGCAydkluZ9jqF8N69x8_86CJZOh3oIZ_F3OAg?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=k230NPDDbSo_q_rDlov07w&_nc_oc=AdlaZXcH4P1SBjAOvXFcNJ-1xPDDmulmLGeliEzSbLa_MIjz6VUCa7Uu4obHdZ38bFw&ccb=10-5&oh=00_AfqmSqFGUzWRETcn9-N_vijvZlsXfB1jh2XyTLQQwJYbsw&oe=6987A7EE&_nc_sid=201bca" s ...

# %% [markdown]
# ## Schritt 4: Bilder lokal speichern
#
# Alle gefundenen Bilder werden als Thumbnails (1024px oder 640px) lokal im Ordner `images_dl/` gespeichert. Dies ist notwendig für die nachfolgende Detektion mit YOLOv5.

# %%
# -------------------------
# 4) Bilder lokal herunterladen
# -------------------------
import os
from urllib.parse import urlparse
from tqdm.notebook import tqdm

def download_images_locally(images, out_dir="images_dl"):
    """
    Lädt Thumbnails lokal herunter und speichert Metadaten.
    """
    os.makedirs(out_dir, exist_ok=True)
    items = []

    for img in tqdm(images, desc="Downloading images"):
        g = img.get("geometry") or {}
        if g.get("type") != "Point":
            continue
        lon, lat = g.get("coordinates", [None, None])
        if lon is None or lat is None:
            continue
        url = img.get("thumb_1024_url") or img.get("thumb_640_url")
        if not url:
            continue
        img_id = img.get("id")
        ext = os.path.splitext(urlparse(url).path)[1] or ".jpg"
        out_path = os.path.join(out_dir, f"{img_id}{ext}")

        try:
            r = requests.get(url, timeout=60)
            if r.status_code == 200:
                with open(out_path, "wb") as f:
                    f.write(r.content)
            else:
                continue
        except Exception:
            continue

        items.append({
            "id": img_id,
            "path": out_path,
            "lat": lat,
            "lon": lon,
            "heading": img.get("computed_compass_angle") if img.get("computed_compass_angle") is not None else img.get("compass_angle"),
            "remote_url": url,
        })
    return items

dl_items = download_images_locally(images, out_dir="images_dl")
print(f"Downloaded locally: {len(dl_items)}")
# Out:
# Downloading images:   0%|          | 0/729 [00:00<?, ?it/s]
# Downloaded locally: 729

# %% [markdown]
# ## Schritt 5: YOLOv5 vorbereiten
#
# Das YOLOv5-Repository wird geklont (falls noch nicht vorhanden) und die Abhängigkeiten werden installiert. Stellen Sie sicher, dass die Modell-Datei `model/best.pt` verfügbar ist.
#
# Quelle: https://huggingface.co/BinKhoaLe1812/Graffiti-Dectection-YOLOv6m

# %%
# -------------------------
# 5) YOLOv5 per Kommandozeile (detect.py) vorbereiten
# -------------------------
import os
import sys
import subprocess
import shlex

# yolov5 klonen (falls nicht vorhanden)
repo_dir = os.path.join(os.getcwd(), "yolov5")
if not os.path.exists(repo_dir):
    cmd = "git clone https://github.com/ultralytics/yolov5"
    print(">", cmd)
    subprocess.run(shlex.split(cmd), check=True)
else:
    print("yolov5 bereits vorhanden; überspringe Klonen.")

# Abhängigkeiten installieren (idempotent)
req_path = os.path.join(repo_dir, "requirements.txt")
if os.path.exists(req_path):
    cmd = f"{sys.executable} -m pip install -r {req_path}"
    print(">", cmd)
    subprocess.run(shlex.split(cmd), check=False)

# Gewichte-Pfad wählen (lokal oder project_base_path, falls vorhanden)
weights_candidates = [os.path.join("model", "best.pt")]
if "project_base_path" in globals():
    cand = os.path.join(project_base_path, "model", "best.pt")
    if os.path.exists(cand):
        weights_candidates.insert(0, cand)

weights = None
for w in weights_candidates:
    if os.path.exists(w):
        weights = w
        break

if not weights:
    raise RuntimeError("Kein Modell gefunden (model/best.pt). Bitte bereitstellen.")

print(f"Verwende Modell: {weights}")

source = os.path.join("images_dl")
project = os.path.join("runs", "graffiti_cli")
name = "exp"

if not os.path.exists(source):
    raise RuntimeError("Verzeichnis images_dl nicht gefunden. Bitte zuerst Thumbnails herunterladen.")

print(f"Quellverzeichnis: {source}")
print(f"Ausgabeverzeichnis: {project}/{name}")
# Out:
# > git clone https://github.com/ultralytics/yolov5
# > /usr/bin/python3 -m pip install -r /content/yolov5/requirements.txt
# Verwende Modell: /content/drive/MyDrive/Teaching_HS/P0002:1_Datenerfassung/github/GeoDatenErfassung25_HS_Mainz/Uebung2/model/best.pt
# Quellverzeichnis: images_dl
# Ausgabeverzeichnis: runs/graffiti_cli/exp

# %% [markdown]
# ## Schritt 6: Graffiti-Detektion ausführen
#
# YOLOv5 wird per Kommandozeile (`detect.py`) auf alle heruntergeladenen Bilder angewendet. Die Ergebnisse (annotierte Bilder und Label-Dateien) werden in `runs/graffiti_cli/exp/` gespeichert.

# %%
# -------------------------
# 6) YOLOv5 Detektion ausführen (mit Live-Output)
# -------------------------
detect_py = os.path.join(repo_dir, "detect.py")

# TODO: Anpassbare Parameter conf und analysieren Sie die Ergebnisse

cmd = shlex.split(
    f"{sys.executable} {detect_py} "
    f"--weights {weights} --source {source} "
    f"--img 1280 --conf 0.25 "
    f"--save-txt --save-conf "
    f"--project {project} --name {name} --exist-ok"
)

process = subprocess.Popen(
    cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)

print("Starting YOLOv5 detection (live output):\n")
print("=" * 60)

for line in process.stdout:
    print(line, end="")

process.wait()

print("=" * 60)

if process.returncode != 0:
    raise RuntimeError(f"YOLOv5 detect.py failed with code {process.returncode}")

print("\n✓ Detection finished successfully.")
# Out:
# Starting YOLOv5 detection (live output):
#
# ============================================================
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# detect: weights=['/content/drive/MyDrive/Teaching_HS/P0002:1_Datenerfassung/github/GeoDatenErfassung25_HS_Mainz/Uebung2/model/best.pt'], source=images_dl, data=yolov5/data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/graffiti_cli, name=exp, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-453-geed9bc19 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# image 1/729 /content/images_dl/1021082162598786.jpg: 960x1280 6 Graffitis, 94.7ms
# image 2/729 /content/images_dl/1021913558379479.jpg: 960x1280 (no detections), 50.6ms
# image 3/729 /content/images_dl/1026509755097521.jpg: 960x1280 1 Graffiti, 50.5ms
# image 4/729 /content/images_dl/1040203593418131.jpg: 960x1280 (no detections), 43.6ms
# image 5/729 /content/images_dl/1046454695760449.jpg: 960x1280 2 Graffitis, 42.2ms
# image 6/729 /content/images_dl/106241234860264.jpg: 960x1280 (no detections), 39.0ms
# image 7/729 /content/images_dl/1080171775803913.jpg: 960x1280 (no detections), 36.2ms
# image 8/729 /content/images_dl/108182281347039.jpg: 960x1280 (no detections), 36.0ms
# image 9/729 /content/images_dl/1085934365266183.jpg: 960x1280 1 Graffiti, 36.1ms
# image 10/729 /content/images_dl/1092670811144374.jpg: 960x1280 (no detections), 35.9ms
# image 11/729 /content/images_dl/1095117400969810.jpg: 960x1280 3 Graffitis, 35.7ms
# image 12/729 /content/images_dl/1095459000943411.jpg: 960x1280 (no detections), 36.0ms
# image 13/729 /content/images_dl/1097659817399034.jpg: 960x1280 (no detections), 36.7ms
# image 14/729 /content/images_dl/1104732293688793.jpg: 960x1280 (no detections), 35.8ms
# image 15/729 /content/images_dl/1105196546642553.jpg: 960x1280 (no detections), 35.7ms
# image 16/729 /content/images_dl/1114859902368083.jpg: 960x1280 (no detections), 36.4ms
# image 17/729 /content/images_dl/1116822359307560.jpg: 960x1280 (no detections), 36.5ms
# image 18/729 /content/images_dl/1118929231850465.jpg: 960x1280 4 Graffitis, 36.1ms
# image 19/729 /content/images_dl/1126981047765942.jpg: 960x1280 (no detections), 35.4ms
# image 20/729 /content/images_dl/1137462973419488.jpg: 960x1280 (no detections), 35.3ms
# image 21/729 /content/images_dl/1139285926570520.jpg: 960x1280 (no detections), 34.9ms
# image 22/729 /content/images_dl/1141980539652445.jpg: 960x1280 (no detections), 34.9ms
# image 23/729 /content/images_dl/1143189929425840.jpg: 960x1280 2 Graffitis, 35.4ms
# image 24/729 /content/images_dl/1145396832572908.jpg: 960x1280 (no detections), 35.3ms
# image 25/729 /content/images_dl/1148498249001530.jpg: 960x1280 (no detections), 36.0ms
# image 26/729 /content/images_dl/1167065573812338.jpg: 960x1280 (no detections), 36.9ms
# image 27/729 /content/images_dl/1167813243696339.jpg: 960x1280 1 Graffiti, 36.7ms
# image 28/729 /content/images_dl/1170325506777343.jpg: 960x1280 1 Graffiti, 35.9ms
# image 29/729 /content/images_dl/1173915773059713.jpg: 960x1280 (no detections), 35.7ms
# image 30/729 /content/images_dl/1179362752517023.jpg: 960x1280 (no detections), 36.3ms
# image 31/729 /content/images_dl/1184532748666772.jpg: 960x1280 1 Graffiti, 40.3ms
# image 32/729 /content/images_dl/1187335311717992.jpg: 960x1280 (no detections), 35.3ms
# image 33/729 /content/images_dl/1198208510612243.jpg: 960x1280 (no detections), 36.1ms
# image 34/729 /content/images_dl/1208600853261368.jpg: 960x1280 (no detections), 35.4ms
# image 35/729 /content/images_dl/1217088495390134.jpg: 960x1280 (no detections), 35.0ms
# image 36/729 /content/images_dl/1222009211608052.jpg: 960x1280 (no detections), 34.8ms
# image 37/729 /content/images_dl/1223565691816089.jpg: 960x1280 3 Graffitis, 35.3ms
# image 38/729 /content/images_dl/1238142419935541.jpg: 960x1280 3 Graffitis, 35.0ms
# image 39/729 /content/images_dl/124746286923138.jpg: 960x1280 (no detections), 33.9ms
# image 40/729 /content/images_dl/1263026090759267.jpg: 960x1280 (no detections), 35.2ms
# image 41/729 /content/images_dl/1277120282686040.jpg: 960x1280 (no detections), 35.4ms
# image 42/729 /content/images_dl/1277983639674518.jpg: 960x1280 (no detections), 34.2ms
# image 43/729 /content/images_dl/1278069865923924.jpg: 960x1280 3 Graffitis, 35.5ms
# image 44/729 /content/images_dl/1290298441665612.jpg: 960x1280 (no detections), 35.7ms
# image 45/729 /content/images_dl/1306854389904302.jpg: 960x1280 1 Graffiti, 35.6ms
# image 46/729 /content/images_dl/131167575617366.jpg: 960x1280 6 Graffitis, 35.4ms
# image 47/729 /content/images_dl/131230039038054.jpg: 960x1280 (no detections), 34.3ms
# image 48/729 /content/images_dl/131460672311011.jpg: 960x1280 (no detections), 35.3ms
# image 49/729 /content/images_dl/131504205633541.jpg: 960x1280 (no detections), 35.2ms
# image 50/729 /content/images_dl/132060282291672.jpg: 960x1280 (no detections), 35.2ms
# image 51/729 /content/images_dl/1326696367725557.jpg: 960x1280 (no detections), 35.2ms
# image 52/729 /content/images_dl/133037705825142.jpg: 960x1280 (no detections), 35.3ms
# image 53/729 /content/images_dl/133394788828156.jpg: 960x1280 (no detections), 35.3ms
# image 54/729 /content/images_dl/1335149030200958.jpg: 960x1280 (no detections), 35.4ms
# image 55/729 /content/images_dl/133544278815661.jpg: 960x1280 (no detections), 35.8ms
# image 56/729 /content/images_dl/133645785421815.jpg: 960x1280 1 Graffiti, 35.4ms
# image 57/729 /content/images_dl/1345574725828845.jpg: 960x1280 (no detections), 35.2ms
# image 58/729 /content/images_dl/1350402335327052.jpg: 960x1280 (no detections), 35.1ms
# image 59/729 /content/images_dl/1370413999986455.jpg: 960x1280 (no detections), 35.9ms
# image 60/729 /content/images_dl/137278475079044.jpg: 960x1280 (no detections), 34.8ms
# image 61/729 /content/images_dl/137420001636887.jpg: 960x1280 2 Graffitis, 35.5ms
# image 62/729 /content/images_dl/137588251680057.jpg: 960x1280 2 Graffitis, 35.2ms
# image 63/729 /content/images_dl/137596534949346.jpg: 960x1280 (no detections), 34.7ms
# image 64/729 /content/images_dl/137701361601442.jpg: 960x1280 1 Graffiti, 35.4ms
# image 65/729 /content/images_dl/1384989465410465.jpg: 960x1280 5 Graffitis, 35.7ms
# image 66/729 /content/images_dl/1396621007403567.jpg: 960x1280 3 Graffitis, 35.2ms
# image 67/729 /content/images_dl/1399034860450971.jpg: 960x1280 (no detections), 35.1ms
# image 68/729 /content/images_dl/140279374779407.jpg: 960x1280 3 Graffitis, 35.3ms
# image 69/729 /content/images_dl/1403661823324675.jpg: 960x1280 2 Graffitis, 34.3ms
# image 70/729 /content/images_dl/1408441019508711.jpg: 960x1280 1 Graffiti, 35.5ms
# image 71/729 /content/images_dl/1408814902839226.jpg: 960x1280 2 Graffitis, 34.6ms
# image 72/729 /content/images_dl/141288701238623.jpg: 960x1280 (no detections), 35.5ms
# image 73/729 /content/images_dl/1416712588696468.jpg: 960x1280 (no detections), 35.2ms
# image 74/729 /content/images_dl/141947458454688.jpg: 960x1280 (no detections), 34.6ms
# image 75/729 /content/images_dl/1420240624983710.jpg: 960x1280 1 Graffiti, 35.2ms
# image 76/729 /content/images_dl/1422141651478916.jpg: 960x1280 1 Graffiti, 35.4ms
# image 77/729 /content/images_dl/1425765127773289.jpg: 960x1280 (no detections), 35.0ms
# image 78/729 /content/images_dl/1425937681080280.jpg: 960x1280 (no detections), 35.6ms
# image 79/729 /content/images_dl/1429953770691127.jpg: 960x1280 7 Graffitis, 35.4ms
# image 80/729 /content/images_dl/143170354443299.jpg: 960x1280 (no detections), 34.9ms
# image 81/729 /content/images_dl/1432812137092827.jpg: 960x1280 1 Graffiti, 35.5ms
# image 82/729 /content/images_dl/143555141077971.jpg: 960x1280 (no detections), 35.0ms
# image 83/729 /content/images_dl/143592554444375.jpg: 960x1280 2 Graffitis, 35.8ms
# image 84/729 /content/images_dl/1447620178918563.jpg: 960x1280 2 Graffitis, 35.4ms
# image 85/729 /content/images_dl/144914274267824.jpg: 960x1280 2 Graffitis, 35.5ms
# image 86/729 /content/images_dl/145171950896892.jpg: 960x1280 2 Graffitis, 35.6ms
# image 87/729 /content/images_dl/1453883021622916.jpg: 960x1280 1 Graffiti, 35.8ms
# image 88/729 /content/images_dl/146323054112389.jpg: 960x1280 (no detections), 35.6ms
# image 89/729 /content/images_dl/146770850742054.jpg: 960x1280 (no detections), 35.7ms
# image 90/729 /content/images_dl/147042660723909.jpg: 960x1280 1 Graffiti, 36.1ms
# image 91/729 /content/images_dl/147099763969227.jpg: 960x1280 (no detections), 35.5ms
# image 92/729 /content/images_dl/147114173968655.jpg: 960x1280 6 Graffitis, 35.3ms
# image 93/729 /content/images_dl/148145663938400.jpg: 960x1280 3 Graffitis, 35.4ms
# image 94/729 /content/images_dl/1488343351529521.jpg: 960x1280 (no detections), 35.6ms
# image 95/729 /content/images_dl/149054677098566.jpg: 960x1280 2 Graffitis, 36.0ms
# image 96/729 /content/images_dl/1491101907903537.jpg: 960x1280 2 Graffitis, 35.8ms
# image 97/729 /content/images_dl/1492657114800092.jpg: 960x1280 (no detections), 36.1ms
# image 98/729 /content/images_dl/149324810474155.jpg: 960x1280 1 Graffiti, 36.9ms
# image 99/729 /content/images_dl/1512126669569000.jpg: 960x1280 (no detections), 36.3ms
# image 100/729 /content/images_dl/1516897198670110.jpg: 960x1280 (no detections), 37.2ms
# image 101/729 /content/images_dl/151937713534949.jpg: 960x1280 (no detections), 36.1ms
# image 102/729 /content/images_dl/151969610198807.jpg: 960x1280 (no detections), 35.5ms
# image 103/729 /content/images_dl/151987433606698.jpg: 736x1280 1 Graffiti, 45.8ms
# image 104/729 /content/images_dl/153089966694759.jpg: 960x1280 (no detections), 34.3ms
# image 105/729 /content/images_dl/154268573298341.jpg: 960x1280 (no detections), 35.6ms
# image 106/729 /content/images_dl/154618289851270.jpg: 960x1280 (no detections), 35.4ms
# image 107/729 /content/images_dl/154934859902405.jpg: 960x1280 1 Graffiti, 36.2ms
# image 108/729 /content/images_dl/155368786535535.jpg: 736x1280 6 Graffitis, 28.7ms
# image 109/729 /content/images_dl/1559086741149096.jpg: 960x1280 (no detections), 35.4ms
# image 110/729 /content/images_dl/156774029781643.jpg: 960x1280 (no detections), 36.0ms
# image 111/729 /content/images_dl/1571716653218784.jpg: 960x1280 5 Graffitis, 35.3ms
# image 112/729 /content/images_dl/1577547742438535.jpg: 960x1280 (no detections), 35.9ms
# image 113/729 /content/images_dl/158103572924055.jpg: 736x1280 4 Graffitis, 29.0ms
# image 114/729 /content/images_dl/158181496146791.jpg: 960x1280 (no detections), 35.1ms
# image 115/729 /content/images_dl/159064639478638.jpg: 960x1280 (no detections), 36.1ms
# image 116/729 /content/images_dl/159069239467978.jpg: 960x1280 1 Graffiti, 36.0ms
# image 117/729 /content/images_dl/1598351087021577.jpg: 960x1280 1 Graffiti, 36.1ms
# image 118/729 /content/images_dl/1607456466132318.jpg: 960x1280 1 Graffiti, 35.5ms
# image 119/729 /content/images_dl/1615747982244798.jpg: 960x1280 (no detections), 35.9ms
# image 120/729 /content/images_dl/161867859090394.jpg: 960x1280 2 Graffitis, 37.0ms
# image 121/729 /content/images_dl/1629376467252967.jpg: 960x1280 2 Graffitis, 36.0ms
# image 122/729 /content/images_dl/1632315960286711.jpg: 960x1280 1 Graffiti, 36.6ms
# image 123/729 /content/images_dl/1637748199762149.jpg: 960x1280 1 Graffiti, 36.6ms
# image 124/729 /content/images_dl/163992488973388.jpg: 960x1280 (no detections), 35.5ms
# image 125/729 /content/images_dl/164774678894992.jpg: 960x1280 (no detections), 37.0ms
# image 126/729 /content/images_dl/164804138898053.jpg: 960x1280 2 Graffitis, 37.2ms
# image 127/729 /content/images_dl/165826428781037.jpg: 960x1280 6 Graffitis, 36.1ms
# image 128/729 /content/images_dl/166093428734101.jpg: 960x1280 (no detections), 35.4ms
# image 129/729 /content/images_dl/166106552068481.jpg: 960x1280 4 Graffitis, 36.8ms
# image 130/729 /content/images_dl/166163055398926.jpg: 960x1280 1 Graffiti, 36.8ms
# image 131/729 /content/images_dl/1661720000688395.jpg: 960x1280 (no detections), 36.5ms
# image 132/729 /content/images_dl/166847212001052.jpg: 960x1280 1 Graffiti, 35.9ms
# image 133/729 /content/images_dl/167241688650196.jpg: 960x1280 (no detections), 35.4ms
# image 134/729 /content/images_dl/167576551851439.jpg: 960x1280 (no detections), 36.2ms
# image 135/729 /content/images_dl/1707248216140734.jpg: 960x1280 (no detections), 34.6ms
# image 136/729 /content/images_dl/171033151565396.jpg: 960x1280 (no detections), 35.4ms
# image 137/729 /content/images_dl/1713187715520746.jpg: 960x1280 1 Graffiti, 35.3ms
# image 138/729 /content/images_dl/171705291513270.jpg: 960x1280 1 Graffiti, 35.4ms
# image 139/729 /content/images_dl/1721366624717017.jpg: 960x1280 (no detections), 35.5ms
# image 140/729 /content/images_dl/172155324805953.jpg: 960x1280 (no detections), 35.6ms
# image 141/729 /content/images_dl/173734957861774.jpg: 960x1280 (no detections), 35.5ms
# image 142/729 /content/images_dl/174022624587023.jpg: 960x1280 4 Graffitis, 36.1ms
# image 143/729 /content/images_dl/175035951178519.jpg: 960x1280 (no detections), 35.2ms
# image 144/729 /content/images_dl/175179904504897.jpg: 960x1280 (no detections), 35.3ms
# image 145/729 /content/images_dl/176935204290324.jpg: 960x1280 (no detections), 35.0ms
# image 146/729 /content/images_dl/177349904243315.jpg: 960x1280 (no detections), 35.5ms
# image 147/729 /content/images_dl/1776482265866964.jpg: 960x1280 (no detections), 35.9ms
# image 148/729 /content/images_dl/177857224192024.jpg: 960x1280 1 Graffiti, 35.6ms
# image 149/729 /content/images_dl/177938747520763.jpg: 960x1280 (no detections), 35.8ms
# image 150/729 /content/images_dl/1780867705424338.jpg: 960x1280 1 Graffiti, 35.7ms
# image 151/729 /content/images_dl/178495834122557.jpg: 960x1280 (no detections), 35.3ms
# image 152/729 /content/images_dl/178669634011397.jpg: 960x1280 2 Graffitis, 36.3ms
# image 153/729 /content/images_dl/179173460658943.jpg: 736x1280 (no detections), 28.9ms
# image 154/729 /content/images_dl/180399977475234.jpg: 960x1280 3 Graffitis, 36.0ms
# image 155/729 /content/images_dl/1807248669436690.jpg: 960x1280 1 Graffiti, 36.3ms
# image 156/729 /content/images_dl/181119197194205.jpg: 960x1280 3 Graffitis, 35.6ms
# image 157/729 /content/images_dl/181134487334020.jpg: 960x1280 1 Graffiti, 36.1ms
# image 158/729 /content/images_dl/181944410935832.jpg: 960x1280 (no detections), 36.4ms
# image 159/729 /content/images_dl/1819662091548155.jpg: 960x1280 (no detections), 36.8ms
# image 160/729 /content/images_dl/1828603120642691.jpg: 960x1280 1 Graffiti, 37.2ms
# image 161/729 /content/images_dl/183604796951914.jpg: 960x1280 1 Graffiti, 36.8ms
# image 162/729 /content/images_dl/183712346943854.jpg: 960x1280 (no detections), 36.3ms
# image 163/729 /content/images_dl/1843891452480932.jpg: 960x1280 (no detections), 36.8ms
# image 164/729 /content/images_dl/1853291371494583.jpg: 960x1280 1 Graffiti, 36.2ms
# image 165/729 /content/images_dl/1863324947181507.jpg: 960x1280 1 Graffiti, 35.6ms
# image 166/729 /content/images_dl/187425219777601.jpg: 960x1280 1 Graffiti, 35.5ms
# image 167/729 /content/images_dl/187513246550194.jpg: 960x1280 (no detections), 36.2ms
# image 168/729 /content/images_dl/187986849837693.jpg: 960x1280 1 Graffiti, 36.2ms
# image 169/729 /content/images_dl/188056526492927.jpg: 960x1280 1 Graffiti, 36.0ms
# image 170/729 /content/images_dl/188177339787954.jpg: 960x1280 2 Graffitis, 35.6ms
# image 171/729 /content/images_dl/1898880590274814.jpg: 960x1280 (no detections), 35.0ms
# image 172/729 /content/images_dl/190125380326972.jpg: 960x1280 (no detections), 35.7ms
# image 173/729 /content/images_dl/190156086325694.jpg: 960x1280 (no detections), 36.3ms
# image 174/729 /content/images_dl/190178192825557.jpg: 960x1280 1 Graffiti, 36.0ms
# image 175/729 /content/images_dl/190624402893878.jpg: 960x1280 (no detections), 35.8ms
# image 176/729 /content/images_dl/1915576375300501.jpg: 960x1280 1 Graffiti, 36.5ms
# image 177/729 /content/images_dl/191717249454162.jpg: 960x1280 2 Graffitis, 37.3ms
# image 178/729 /content/images_dl/1922279967949718.jpg: 960x1280 (no detections), 36.6ms
# image 179/729 /content/images_dl/192750556001516.jpg: 960x1280 (no detections), 36.2ms
# image 180/729 /content/images_dl/193853935910971.jpg: 960x1280 (no detections), 36.6ms
# image 181/729 /content/images_dl/1940166902824402.jpg: 960x1280 2 Graffitis, 36.1ms
# image 182/729 /content/images_dl/1947225608786115.jpg: 960x1280 2 Graffitis, 35.6ms
# image 183/729 /content/images_dl/195037115797176.jpg: 960x1280 (no detections), 34.7ms
# image 184/729 /content/images_dl/195087935790792.jpg: 960x1280 1 Graffiti, 34.5ms
# image 185/729 /content/images_dl/196526362311520.jpg: 960x1280 (no detections), 38.0ms
# image 186/729 /content/images_dl/198373875454666.jpg: 960x1280 (no detections), 36.6ms
# image 187/729 /content/images_dl/1998907393589828.jpg: 960x1280 (no detections), 36.8ms
# image 188/729 /content/images_dl/200236958399183.jpg: 960x1280 (no detections), 36.4ms
# image 189/729 /content/images_dl/201048738531721.jpg: 960x1280 (no detections), 36.5ms
# image 190/729 /content/images_dl/203012788091163.jpg: 960x1280 2 Graffitis, 37.0ms
# image 191/729 /content/images_dl/2032195156918798.jpg: 960x1280 (no detections), 35.9ms
# image 192/729 /content/images_dl/208656947757863.jpg: 736x1280 (no detections), 29.5ms
# image 193/729 /content/images_dl/210605547213885.jpg: 960x1280 (no detections), 37.1ms
# image 194/729 /content/images_dl/2109773795832252.jpg: 960x1280 (no detections), 36.6ms
# image 195/729 /content/images_dl/211122904109620.jpg: 960x1280 (no detections), 36.4ms
# image 196/729 /content/images_dl/211512050777848.jpg: 960x1280 (no detections), 36.5ms
# image 197/729 /content/images_dl/211792787379434.jpg: 960x1280 (no detections), 36.0ms
# image 198/729 /content/images_dl/213583633619955.jpg: 960x1280 (no detections), 36.9ms
# image 199/729 /content/images_dl/213636187238819.jpg: 960x1280 (no detections), 37.3ms
# image 200/729 /content/images_dl/213935060179548.jpg: 960x1280 1 Graffiti, 36.9ms
# image 201/729 /content/images_dl/214414758198008.jpg: 960x1280 7 Graffitis, 35.9ms
# image 202/729 /content/images_dl/215169650016770.jpg: 960x1280 (no detections), 35.4ms
# image 203/729 /content/images_dl/216292273223256.jpg: 960x1280 1 Graffiti, 36.3ms
# image 204/729 /content/images_dl/216929579876359.jpg: 960x1280 (no detections), 35.5ms
# image 205/729 /content/images_dl/219973776555538.jpg: 960x1280 3 Graffitis, 37.1ms
# image 206/729 /content/images_dl/221437852771627.jpg: 960x1280 (no detections), 35.6ms
# image 207/729 /content/images_dl/221786855990327.jpg: 960x1280 (no detections), 35.8ms
# image 208/729 /content/images_dl/222913062505520.jpg: 960x1280 (no detections), 35.9ms
# image 209/729 /content/images_dl/223183262900896.jpg: 960x1280 1 Graffiti, 35.6ms
# image 210/729 /content/images_dl/224142692817631.jpg: 960x1280 1 Graffiti, 35.2ms
# image 211/729 /content/images_dl/2241966869270028.jpg: 960x1280 (no detections), 35.9ms
# image 212/729 /content/images_dl/2243447985787214.jpg: 960x1280 (no detections), 36.0ms
# image 213/729 /content/images_dl/224660042755797.jpg: 960x1280 1 Graffiti, 36.5ms
# image 214/729 /content/images_dl/227299022495104.jpg: 960x1280 (no detections), 35.9ms
# image 215/729 /content/images_dl/229032975659152.jpg: 960x1280 (no detections), 36.2ms
# image 216/729 /content/images_dl/232381878665118.jpg: 960x1280 (no detections), 37.5ms
# image 217/729 /content/images_dl/233998775165718.jpg: 960x1280 (no detections), 36.5ms
# image 218/729 /content/images_dl/234443948434630.jpg: 960x1280 4 Graffitis, 35.9ms
# image 219/729 /content/images_dl/237044661340694.jpg: 960x1280 (no detections), 35.1ms
# image 220/729 /content/images_dl/237782118140986.jpg: 736x1280 (no detections), 28.8ms
# image 221/729 /content/images_dl/242153757664778.jpg: 960x1280 (no detections), 35.3ms
# image 222/729 /content/images_dl/244712050762787.jpg: 960x1280 (no detections), 35.9ms
# image 223/729 /content/images_dl/245093830697935.jpg: 960x1280 (no detections), 35.7ms
# image 224/729 /content/images_dl/2469989756472640.jpg: 960x1280 3 Graffitis, 35.9ms
# image 225/729 /content/images_dl/248108423724193.jpg: 960x1280 (no detections), 35.2ms
# image 226/729 /content/images_dl/249971630188909.jpg: 960x1280 (no detections), 35.6ms
# image 227/729 /content/images_dl/250345386828611.jpg: 960x1280 1 Graffiti, 36.4ms
# image 228/729 /content/images_dl/252962489860571.jpg: 960x1280 1 Graffiti, 35.9ms
# image 229/729 /content/images_dl/253381386476330.jpg: 960x1280 2 Graffitis, 35.3ms
# image 230/729 /content/images_dl/254776763002590.jpg: 960x1280 1 Graffiti, 36.2ms
# image 231/729 /content/images_dl/2551078768521809.jpg: 960x1280 (no detections), 36.5ms
# image 232/729 /content/images_dl/255294716390636.jpg: 960x1280 (no detections), 37.2ms
# image 233/729 /content/images_dl/2557588431211006.jpg: 960x1280 (no detections), 36.2ms
# image 234/729 /content/images_dl/257147769492519.jpg: 960x1280 (no detections), 35.9ms
# image 235/729 /content/images_dl/257349556130146.jpg: 960x1280 (no detections), 35.5ms
# image 236/729 /content/images_dl/259430859300165.jpg: 736x1280 2 Graffitis, 29.0ms
# image 237/729 /content/images_dl/261341759064058.jpg: 960x1280 1 Graffiti, 35.4ms
# image 238/729 /content/images_dl/261953555661231.jpg: 960x1280 (no detections), 35.4ms
# image 239/729 /content/images_dl/262930528893148.jpg: 960x1280 1 Graffiti, 35.9ms
# image 240/729 /content/images_dl/265399695319234.jpg: 960x1280 1 Graffiti, 35.7ms
# image 241/729 /content/images_dl/266563182644152.jpg: 960x1280 4 Graffitis, 36.7ms
# image 242/729 /content/images_dl/266842279192289.jpg: 960x1280 6 Graffitis, 36.7ms
# image 243/729 /content/images_dl/268948758266194.jpg: 960x1280 (no detections), 36.1ms
# image 244/729 /content/images_dl/270688588705067.jpg: 960x1280 2 Graffitis, 36.7ms
# image 245/729 /content/images_dl/2708401236126723.jpg: 960x1280 (no detections), 36.6ms
# image 246/729 /content/images_dl/271168011364301.jpg: 960x1280 (no detections), 36.6ms
# image 247/729 /content/images_dl/2714931795464906.jpg: 960x1280 4 Graffitis, 36.5ms
# image 248/729 /content/images_dl/273088195214163.jpg: 960x1280 2 Graffitis, 36.0ms
# image 249/729 /content/images_dl/273725937802698.jpg: 960x1280 (no detections), 35.9ms
# image 250/729 /content/images_dl/2759299767715901.jpg: 960x1280 (no detections), 36.1ms
# image 251/729 /content/images_dl/276642780843749.jpg: 960x1280 2 Graffitis, 36.1ms
# image 252/729 /content/images_dl/277210467412554.jpg: 960x1280 3 Graffitis, 36.9ms
# image 253/729 /content/images_dl/277583497368217.jpg: 960x1280 4 Graffitis, 36.5ms
# image 254/729 /content/images_dl/277857361424692.jpg: 960x1280 1 Graffiti, 35.0ms
# image 255/729 /content/images_dl/278142194025175.jpg: 960x1280 1 Graffiti, 34.6ms
# image 256/729 /content/images_dl/278378800660295.jpg: 960x1280 (no detections), 35.2ms
# image 257/729 /content/images_dl/279804951103478.jpg: 960x1280 6 Graffitis, 35.4ms
# image 258/729 /content/images_dl/280198981086296.jpg: 960x1280 8 Graffitis, 35.6ms
# image 259/729 /content/images_dl/280285457069231.jpg: 960x1280 1 Graffiti, 34.1ms
# image 260/729 /content/images_dl/280411680457990.jpg: 960x1280 (no detections), 35.2ms
# image 261/729 /content/images_dl/281612587041702.jpg: 960x1280 1 Graffiti, 35.8ms
# image 262/729 /content/images_dl/281832763577134.jpg: 960x1280 (no detections), 35.0ms
# image 263/729 /content/images_dl/281960420304397.jpg: 960x1280 1 Graffiti, 35.2ms
# image 264/729 /content/images_dl/282118140124898.jpg: 960x1280 5 Graffitis, 35.1ms
# image 265/729 /content/images_dl/282134726861427.jpg: 960x1280 (no detections), 35.5ms
# image 266/729 /content/images_dl/282294633616109.jpg: 960x1280 1 Graffiti, 35.9ms
# image 267/729 /content/images_dl/282845650233113.jpg: 960x1280 4 Graffitis, 35.1ms
# image 268/729 /content/images_dl/283004666801994.jpg: 960x1280 (no detections), 35.4ms
# image 269/729 /content/images_dl/2840378129609098.jpg: 960x1280 (no detections), 35.2ms
# image 270/729 /content/images_dl/2841727236092173.jpg: 960x1280 (no detections), 34.9ms
# image 271/729 /content/images_dl/284394103341821.jpg: 960x1280 (no detections), 35.8ms
# image 272/729 /content/images_dl/284395166650643.jpg: 960x1280 1 Graffiti, 35.7ms
# image 273/729 /content/images_dl/2850986725160692.jpg: 960x1280 (no detections), 35.2ms
# image 274/729 /content/images_dl/285508579799029.jpg: 960x1280 3 Graffitis, 35.8ms
# image 275/729 /content/images_dl/286166469823572.jpg: 960x1280 4 Graffitis, 35.5ms
# image 276/729 /content/images_dl/2872245023036693.jpg: 960x1280 1 Graffiti, 35.9ms
# image 277/729 /content/images_dl/287792916271798.jpg: 960x1280 (no detections), 35.2ms
# image 278/729 /content/images_dl/287993942958977.jpg: 960x1280 (no detections), 35.8ms
# image 279/729 /content/images_dl/2881074292177368.jpg: 960x1280 1 Graffiti, 35.8ms
# image 280/729 /content/images_dl/288268112974923.jpg: 960x1280 3 Graffitis, 35.3ms
# image 281/729 /content/images_dl/288659812862445.jpg: 960x1280 (no detections), 35.5ms
# image 282/729 /content/images_dl/2889012658034242.jpg: 960x1280 (no detections), 35.8ms
# image 283/729 /content/images_dl/2891412601139235.jpg: 960x1280 (no detections), 35.5ms
# image 284/729 /content/images_dl/2896956510517402.jpg: 960x1280 (no detections), 35.3ms
# image 285/729 /content/images_dl/2901009133453374.jpg: 960x1280 (no detections), 35.1ms
# image 286/729 /content/images_dl/290178216054750.jpg: 960x1280 (no detections), 35.5ms
# image 287/729 /content/images_dl/290233056102650.jpg: 960x1280 2 Graffitis, 35.4ms
# image 288/729 /content/images_dl/290496842721570.jpg: 960x1280 (no detections), 35.2ms
# image 289/729 /content/images_dl/2907647036229681.jpg: 960x1280 (no detections), 35.7ms
# image 290/729 /content/images_dl/291091215971689.jpg: 960x1280 (no detections), 35.6ms
# image 291/729 /content/images_dl/292261212391584.jpg: 960x1280 (no detections), 34.6ms
# image 292/729 /content/images_dl/292821682307671.jpg: 960x1280 (no detections), 35.7ms
# image 293/729 /content/images_dl/2935564483388184.jpg: 960x1280 (no detections), 35.4ms
# image 294/729 /content/images_dl/293571922259609.jpg: 736x1280 1 Graffiti, 29.2ms
# image 295/729 /content/images_dl/293850289073897.jpg: 960x1280 (no detections), 34.7ms
# image 296/729 /content/images_dl/2943180092591538.jpg: 960x1280 (no detections), 35.5ms
# image 297/729 /content/images_dl/294619278825421.jpg: 960x1280 (no detections), 35.7ms
# image 298/729 /content/images_dl/295384578838816.jpg: 960x1280 (no detections), 35.2ms
# image 299/729 /content/images_dl/2955302838036893.jpg: 960x1280 (no detections), 35.5ms
# image 300/729 /content/images_dl/295658295394709.jpg: 960x1280 (no detections), 36.0ms
# image 301/729 /content/images_dl/2960834940910547.jpg: 960x1280 1 Graffiti, 36.1ms
# image 302/729 /content/images_dl/296357465397160.jpg: 960x1280 2 Graffitis, 35.6ms
# image 303/729 /content/images_dl/296421765255908.jpg: 960x1280 2 Graffitis, 34.6ms
# image 304/729 /content/images_dl/296618901944049.jpg: 960x1280 1 Graffiti, 35.9ms
# image 305/729 /content/images_dl/296797638590917.jpg: 736x1280 (no detections), 29.0ms
# image 306/729 /content/images_dl/297021078694785.jpg: 960x1280 (no detections), 35.7ms
# image 307/729 /content/images_dl/297246931888325.jpg: 960x1280 (no detections), 35.6ms
# image 308/729 /content/images_dl/297282225196091.jpg: 960x1280 9 Graffitis, 35.8ms
# image 309/729 /content/images_dl/297731238593011.jpg: 960x1280 5 Graffitis, 35.5ms
# image 310/729 /content/images_dl/297795921961914.jpg: 960x1280 (no detections), 35.3ms
# image 311/729 /content/images_dl/297974755255002.jpg: 960x1280 2 Graffitis, 36.3ms
# image 312/729 /content/images_dl/298040881917028.jpg: 736x1280 2 Graffitis, 28.8ms
# image 313/729 /content/images_dl/298174955264023.jpg: 960x1280 (no detections), 35.9ms
# image 314/729 /content/images_dl/2987055294953263.jpg: 960x1280 2 Graffitis, 36.8ms
# image 315/729 /content/images_dl/299164485000461.jpg: 960x1280 2 Graffitis, 36.1ms
# image 316/729 /content/images_dl/2995493977396762.jpg: 960x1280 2 Graffitis, 36.0ms
# image 317/729 /content/images_dl/2998463580441059.jpg: 960x1280 1 Graffiti, 35.8ms
# image 318/729 /content/images_dl/2998953740391776.jpg: 960x1280 (no detections), 36.1ms
# image 319/729 /content/images_dl/299971471709824.jpg: 960x1280 2 Graffitis, 36.4ms
# image 320/729 /content/images_dl/300893528377453.jpg: 960x1280 1 Graffiti, 35.6ms
# image 321/729 /content/images_dl/3010492052608668.jpg: 960x1280 7 Graffitis, 35.8ms
# image 322/729 /content/images_dl/3021435334756858.jpg: 960x1280 (no detections), 35.1ms
# image 323/729 /content/images_dl/302429361465814.jpg: 960x1280 4 Graffitis, 36.2ms
# image 324/729 /content/images_dl/3027855947540745.jpg: 960x1280 (no detections), 35.6ms
# image 325/729 /content/images_dl/303833524640476.jpg: 960x1280 1 Graffiti, 35.7ms
# image 326/729 /content/images_dl/304069837966345.jpg: 960x1280 (no detections), 37.2ms
# image 327/729 /content/images_dl/304173201313930.jpg: 960x1280 1 Graffiti, 37.7ms
# image 328/729 /content/images_dl/304253281304288.jpg: 960x1280 (no detections), 36.6ms
# image 329/729 /content/images_dl/304509414528203.jpg: 960x1280 (no detections), 36.0ms
# image 330/729 /content/images_dl/305114364461568.jpg: 960x1280 (no detections), 36.2ms
# image 331/729 /content/images_dl/305251104545207.jpg: 960x1280 (no detections), 36.3ms
# image 332/729 /content/images_dl/306236017566187.jpg: 960x1280 1 Graffiti, 37.1ms
# image 333/729 /content/images_dl/306367221097961.jpg: 960x1280 (no detections), 36.4ms
# image 334/729 /content/images_dl/306776627496950.jpg: 960x1280 2 Graffitis, 36.6ms
# image 335/729 /content/images_dl/306919481857641.jpg: 960x1280 (no detections), 36.2ms
# image 336/729 /content/images_dl/307038980833511.jpg: 960x1280 4 Graffitis, 36.3ms
# image 337/729 /content/images_dl/307294290837767.jpg: 960x1280 (no detections), 36.0ms
# image 338/729 /content/images_dl/3077319012554437.jpg: 960x1280 1 Graffiti, 36.4ms
# image 339/729 /content/images_dl/307838150785356.jpg: 960x1280 1 Graffiti, 35.9ms
# image 340/729 /content/images_dl/308075567369471.jpg: 960x1280 1 Graffiti, 35.9ms
# image 341/729 /content/images_dl/308299050679424.jpg: 960x1280 (no detections), 35.8ms
# image 342/729 /content/images_dl/309388770543710.jpg: 960x1280 1 Graffiti, 35.9ms
# image 343/729 /content/images_dl/309403647291938.jpg: 960x1280 1 Graffiti, 36.1ms
# image 344/729 /content/images_dl/310192070455915.jpg: 960x1280 5 Graffitis, 35.9ms
# image 345/729 /content/images_dl/310652767119477.jpg: 960x1280 (no detections), 36.0ms
# image 346/729 /content/images_dl/311113043907182.jpg: 960x1280 (no detections), 36.7ms
# image 347/729 /content/images_dl/312584730534054.jpg: 960x1280 (no detections), 35.8ms
# image 348/729 /content/images_dl/313195610315935.jpg: 960x1280 (no detections), 36.6ms
# image 349/729 /content/images_dl/315606166595531.jpg: 960x1280 (no detections), 36.4ms
# image 350/729 /content/images_dl/315725103322548.jpg: 960x1280 4 Graffitis, 37.2ms
# image 351/729 /content/images_dl/3158287357724957.jpg: 960x1280 (no detections), 36.2ms
# image 352/729 /content/images_dl/315958846716160.jpg: 960x1280 8 Graffitis, 36.6ms
# image 353/729 /content/images_dl/316112996614118.jpg: 960x1280 1 Graffiti, 36.1ms
# image 354/729 /content/images_dl/3163548260550298.jpg: 960x1280 (no detections), 36.0ms
# image 355/729 /content/images_dl/317594666445322.jpg: 960x1280 4 Graffitis, 37.0ms
# image 356/729 /content/images_dl/317796993037508.jpg: 960x1280 (no detections), 36.0ms
# image 357/729 /content/images_dl/319726336409988.jpg: 960x1280 (no detections), 36.1ms
# image 358/729 /content/images_dl/321539936064344.jpg: 960x1280 3 Graffitis, 36.2ms
# image 359/729 /content/images_dl/322227792656424.jpg: 960x1280 (no detections), 36.0ms
# image 360/729 /content/images_dl/324667415673791.jpg: 960x1280 (no detections), 36.9ms
# image 361/729 /content/images_dl/3268171000075909.jpg: 960x1280 (no detections), 37.3ms
# image 362/729 /content/images_dl/327302352102107.jpg: 960x1280 (no detections), 36.6ms
# image 363/729 /content/images_dl/327717165381831.jpg: 960x1280 (no detections), 37.0ms
# image 364/729 /content/images_dl/328134648668343.jpg: 960x1280 1 Graffiti, 35.9ms
# image 365/729 /content/images_dl/329712809238685.jpg: 960x1280 (no detections), 35.9ms
# image 366/729 /content/images_dl/330082988481759.jpg: 960x1280 1 Graffiti, 36.1ms
# image 367/729 /content/images_dl/330217365333172.jpg: 960x1280 (no detections), 36.7ms
# image 368/729 /content/images_dl/332531198296392.jpg: 960x1280 (no detections), 37.0ms
# image 369/729 /content/images_dl/333895088067702.jpg: 960x1280 (no detections), 37.5ms
# image 370/729 /content/images_dl/334485561344956.jpg: 960x1280 4 Graffitis, 36.7ms
# image 371/729 /content/images_dl/335516687911279.jpg: 960x1280 (no detections), 35.6ms
# image 372/729 /content/images_dl/337318364655814.jpg: 960x1280 (no detections), 39.0ms
# image 373/729 /content/images_dl/3398896116880074.jpg: 960x1280 (no detections), 39.1ms
# image 374/729 /content/images_dl/346943900372817.jpg: 960x1280 (no detections), 35.9ms
# image 375/729 /content/images_dl/3499517383482540.jpg: 960x1280 1 Graffiti, 36.6ms
# image 376/729 /content/images_dl/3514168695350692.jpg: 960x1280 (no detections), 36.4ms
# image 377/729 /content/images_dl/361720792041880.jpg: 960x1280 (no detections), 36.6ms
# image 378/729 /content/images_dl/363781135049140.jpg: 960x1280 1 Graffiti, 36.6ms
# image 379/729 /content/images_dl/366005944875420.jpg: 960x1280 (no detections), 36.7ms
# image 380/729 /content/images_dl/366306708106980.jpg: 960x1280 1 Graffiti, 36.1ms
# image 381/729 /content/images_dl/3667894563434794.jpg: 960x1280 (no detections), 35.7ms
# image 382/729 /content/images_dl/366973311410727.jpg: 736x1280 (no detections), 28.9ms
# image 383/729 /content/images_dl/3671813649613652.jpg: 960x1280 (no detections), 35.6ms
# image 384/729 /content/images_dl/367441111308438.jpg: 960x1280 1 Graffiti, 36.0ms
# image 385/729 /content/images_dl/3675728909205222.jpg: 960x1280 (no detections), 36.3ms
# image 386/729 /content/images_dl/367780967943060.jpg: 960x1280 2 Graffitis, 36.4ms
# image 387/729 /content/images_dl/368269681179573.jpg: 960x1280 1 Graffiti, 36.3ms
# image 388/729 /content/images_dl/368406837844369.jpg: 960x1280 2 Graffitis, 37.5ms
# image 389/729 /content/images_dl/368724331143936.jpg: 960x1280 (no detections), 36.3ms
# image 390/729 /content/images_dl/369391527750696.jpg: 960x1280 1 Graffiti, 38.2ms
# image 391/729 /content/images_dl/369766121031466.jpg: 960x1280 (no detections), 36.5ms
# image 392/729 /content/images_dl/370495647610518.jpg: 960x1280 (no detections), 36.1ms
# image 393/729 /content/images_dl/370812837579752.jpg: 960x1280 (no detections), 36.5ms
# image 394/729 /content/images_dl/370970134220024.jpg: 960x1280 (no detections), 35.6ms
# image 395/729 /content/images_dl/371395941969173.jpg: 960x1280 4 Graffitis, 35.1ms
# image 396/729 /content/images_dl/372126730792920.jpg: 960x1280 (no detections), 36.0ms
# image 397/729 /content/images_dl/3721724794605647.jpg: 960x1280 1 Graffiti, 36.0ms
# image 398/729 /content/images_dl/373152240790919.jpg: 960x1280 3 Graffitis, 37.0ms
# image 399/729 /content/images_dl/3733787760083575.jpg: 960x1280 2 Graffitis, 36.8ms
# image 400/729 /content/images_dl/3744839345644250.jpg: 960x1280 1 Graffiti, 37.2ms
# image 401/729 /content/images_dl/378427543371019.jpg: 960x1280 4 Graffitis, 36.3ms
# image 402/729 /content/images_dl/378888353328335.jpg: 960x1280 (no detections), 36.0ms
# image 403/729 /content/images_dl/379083503301207.jpg: 960x1280 (no detections), 37.1ms
# image 404/729 /content/images_dl/381822849714970.jpg: 960x1280 (no detections), 37.5ms
# image 405/729 /content/images_dl/382423999665422.jpg: 960x1280 (no detections), 36.9ms
# image 406/729 /content/images_dl/383101229489541.jpg: 960x1280 1 Graffiti, 36.4ms
# image 407/729 /content/images_dl/383313750458957.jpg: 960x1280 (no detections), 36.3ms
# image 408/729 /content/images_dl/3873956812723102.jpg: 960x1280 2 Graffitis, 36.7ms
# image 409/729 /content/images_dl/3875987199151963.jpg: 960x1280 (no detections), 36.1ms
# image 410/729 /content/images_dl/388281615648754.jpg: 960x1280 (no detections), 36.2ms
# image 411/729 /content/images_dl/3885295041567551.jpg: 960x1280 1 Graffiti, 36.5ms
# image 412/729 /content/images_dl/3913605998753656.jpg: 960x1280 (no detections), 35.9ms
# image 413/729 /content/images_dl/393346809529313.jpg: 960x1280 (no detections), 36.5ms
# image 414/729 /content/images_dl/3947772501969395.jpg: 960x1280 (no detections), 36.4ms
# image 415/729 /content/images_dl/3947900731942115.jpg: 960x1280 (no detections), 36.9ms
# image 416/729 /content/images_dl/3959507040837228.jpg: 960x1280 (no detections), 37.6ms
# image 417/729 /content/images_dl/396188274704405.jpg: 960x1280 1 Graffiti, 38.6ms
# image 418/729 /content/images_dl/3961913830583441.jpg: 960x1280 3 Graffitis, 35.4ms
# image 419/729 /content/images_dl/3974308026017438.jpg: 960x1280 1 Graffiti, 36.4ms
# image 420/729 /content/images_dl/4021089227981056.jpg: 960x1280 (no detections), 37.0ms
# image 421/729 /content/images_dl/405996727507446.jpg: 960x1280 1 Graffiti, 36.4ms
# image 422/729 /content/images_dl/4060820597298229.jpg: 960x1280 1 Graffiti, 35.7ms
# image 423/729 /content/images_dl/4063282103739361.jpg: 960x1280 1 Graffiti, 35.9ms
# image 424/729 /content/images_dl/4070722629637390.jpg: 960x1280 (no detections), 36.0ms
# image 425/729 /content/images_dl/410359974367486.jpg: 960x1280 (no detections), 36.2ms
# image 426/729 /content/images_dl/416113640484128.jpg: 960x1280 (no detections), 36.4ms
# image 427/729 /content/images_dl/417610900301430.jpg: 960x1280 (no detections), 36.9ms
# image 428/729 /content/images_dl/418706046880057.jpg: 960x1280 (no detections), 36.8ms
# image 429/729 /content/images_dl/419154325781427.jpg: 960x1280 (no detections), 36.2ms
# image 430/729 /content/images_dl/4193797623984782.jpg: 960x1280 (no detections), 37.5ms
# image 431/729 /content/images_dl/4236672746363447.jpg: 960x1280 (no detections), 36.9ms
# image 432/729 /content/images_dl/4264953990194924.jpg: 960x1280 2 Graffitis, 36.7ms
# image 433/729 /content/images_dl/4340490626043840.jpg: 960x1280 6 Graffitis, 35.6ms
# image 434/729 /content/images_dl/437929904650190.jpg: 960x1280 (no detections), 35.8ms
# image 435/729 /content/images_dl/4379744288716331.jpg: 960x1280 (no detections), 36.5ms
# image 436/729 /content/images_dl/440571630670319.jpg: 960x1280 2 Graffitis, 36.9ms
# image 437/729 /content/images_dl/448888979537892.jpg: 960x1280 (no detections), 35.5ms
# image 438/729 /content/images_dl/450636613218838.jpg: 960x1280 (no detections), 37.0ms
# image 439/729 /content/images_dl/451412042626863.jpg: 960x1280 2 Graffitis, 36.6ms
# image 440/729 /content/images_dl/453733295928921.jpg: 960x1280 (no detections), 36.5ms
# image 441/729 /content/images_dl/454630119170840.jpg: 960x1280 (no detections), 36.9ms
# image 442/729 /content/images_dl/454659212297930.jpg: 960x1280 (no detections), 37.3ms
# image 443/729 /content/images_dl/454732109413985.jpg: 960x1280 1 Graffiti, 37.4ms
# image 444/729 /content/images_dl/454887869133843.jpg: 960x1280 (no detections), 36.6ms
# image 445/729 /content/images_dl/455262759111752.jpg: 960x1280 (no detections), 36.8ms
# image 446/729 /content/images_dl/456046135659102.jpg: 960x1280 (no detections), 36.9ms
# image 447/729 /content/images_dl/4569541819729870.jpg: 960x1280 (no detections), 37.0ms
# image 448/729 /content/images_dl/457151472253279.jpg: 960x1280 (no detections), 35.6ms
# image 449/729 /content/images_dl/457171115389706.jpg: 960x1280 (no detections), 36.4ms
# image 450/729 /content/images_dl/457501518676645.jpg: 736x1280 3 Graffitis, 29.3ms
# image 451/729 /content/images_dl/457785278623339.jpg: 960x1280 (no detections), 35.2ms
# image 452/729 /content/images_dl/457843465496324.jpg: 960x1280 1 Graffiti, 36.1ms
# image 453/729 /content/images_dl/458625391913125.jpg: 960x1280 1 Graffiti, 36.0ms
# image 454/729 /content/images_dl/458908062741183.jpg: 960x1280 (no detections), 35.6ms
# image 455/729 /content/images_dl/459311301806851.jpg: 960x1280 2 Graffitis, 36.6ms
# image 456/729 /content/images_dl/460223301735467.jpg: 960x1280 (no detections), 35.6ms
# image 457/729 /content/images_dl/461608131598755.jpg: 960x1280 1 Graffiti, 35.8ms
# image 458/729 /content/images_dl/461944128220115.jpg: 960x1280 (no detections), 36.7ms
# image 459/729 /content/images_dl/462525041503365.jpg: 960x1280 (no detections), 36.2ms
# image 460/729 /content/images_dl/462760234835753.jpg: 960x1280 (no detections), 36.9ms
# image 461/729 /content/images_dl/463084121459795.jpg: 960x1280 (no detections), 37.4ms
# image 462/729 /content/images_dl/463657431398539.jpg: 960x1280 2 Graffitis, 36.5ms
# image 463/729 /content/images_dl/463831434851096.jpg: 960x1280 1 Graffiti, 36.1ms
# image 464/729 /content/images_dl/464329568153928.jpg: 960x1280 1 Graffiti, 35.9ms
# image 465/729 /content/images_dl/464818558182298.jpg: 960x1280 (no detections), 36.1ms
# image 466/729 /content/images_dl/465061674580601.jpg: 960x1280 3 Graffitis, 36.7ms
# image 467/729 /content/images_dl/467172451230062.jpg: 960x1280 (no detections), 36.0ms
# image 468/729 /content/images_dl/467239970995057.jpg: 960x1280 1 Graffiti, 37.1ms
# image 469/729 /content/images_dl/467576274667765.jpg: 960x1280 (no detections), 36.7ms
# image 470/729 /content/images_dl/468155110910378.jpg: 960x1280 2 Graffitis, 36.8ms
# image 471/729 /content/images_dl/4690432640972350.jpg: 960x1280 (no detections), 36.2ms
# image 472/729 /content/images_dl/469685077580498.jpg: 960x1280 1 Graffiti, 36.5ms
# image 473/729 /content/images_dl/469977704255507.jpg: 960x1280 3 Graffitis, 35.6ms
# image 474/729 /content/images_dl/470763110697657.jpg: 960x1280 (no detections), 35.3ms
# image 475/729 /content/images_dl/471199100878917.jpg: 960x1280 3 Graffitis, 35.9ms
# image 476/729 /content/images_dl/471254633953759.jpg: 960x1280 (no detections), 34.6ms
# image 477/729 /content/images_dl/472262300555887.jpg: 960x1280 1 Graffiti, 36.0ms
# image 478/729 /content/images_dl/472902247160539.jpg: 960x1280 1 Graffiti, 35.0ms
# image 479/729 /content/images_dl/473543823969082.jpg: 960x1280 (no detections), 35.6ms
# image 480/729 /content/images_dl/473746650552968.jpg: 960x1280 (no detections), 35.2ms
# image 481/729 /content/images_dl/473811557240552.jpg: 960x1280 (no detections), 34.9ms
# image 482/729 /content/images_dl/474120640536412.jpg: 960x1280 1 Graffiti, 35.5ms
# image 483/729 /content/images_dl/474130930528810.jpg: 960x1280 (no detections), 35.6ms
# image 484/729 /content/images_dl/474573983851851.jpg: 960x1280 4 Graffitis, 35.4ms
# image 485/729 /content/images_dl/474829940303423.jpg: 960x1280 (no detections), 35.5ms
# image 486/729 /content/images_dl/476345087019276.jpg: 960x1280 (no detections), 36.1ms
# image 487/729 /content/images_dl/476355203603712.jpg: 960x1280 (no detections), 35.6ms
# image 488/729 /content/images_dl/476404736804488.jpg: 960x1280 (no detections), 35.1ms
# image 489/729 /content/images_dl/477355703516816.jpg: 960x1280 1 Graffiti, 36.2ms
# image 490/729 /content/images_dl/478177563390293.jpg: 960x1280 (no detections), 35.2ms
# image 491/729 /content/images_dl/478605556718368.jpg: 960x1280 2 Graffitis, 35.9ms
# image 492/729 /content/images_dl/479742746777375.jpg: 960x1280 (no detections), 35.7ms
# image 493/729 /content/images_dl/481839423051547.jpg: 960x1280 (no detections), 36.0ms
# image 494/729 /content/images_dl/481880163131049.jpg: 960x1280 9 Graffitis, 35.6ms
# image 495/729 /content/images_dl/482279072827724.jpg: 960x1280 (no detections), 34.8ms
# image 496/729 /content/images_dl/484325646317188.jpg: 960x1280 1 Graffiti, 36.3ms
# image 497/729 /content/images_dl/484701916287402.jpg: 960x1280 (no detections), 35.6ms
# image 498/729 /content/images_dl/485431502906224.jpg: 960x1280 (no detections), 36.0ms
# image 499/729 /content/images_dl/485635009305414.jpg: 960x1280 1 Graffiti, 35.5ms
# image 500/729 /content/images_dl/485944535988182.jpg: 960x1280 2 Graffitis, 35.7ms
# image 501/729 /content/images_dl/487741939156448.jpg: 960x1280 (no detections), 35.1ms
# image 502/729 /content/images_dl/488805005874101.jpg: 736x1280 (no detections), 28.9ms
# image 503/729 /content/images_dl/489124739105017.jpg: 960x1280 (no detections), 35.7ms
# image 504/729 /content/images_dl/489162788865591.jpg: 960x1280 (no detections), 35.3ms
# image 505/729 /content/images_dl/490950952320370.jpg: 960x1280 (no detections), 36.0ms
# image 506/729 /content/images_dl/491429032201927.jpg: 960x1280 (no detections), 36.2ms
# image 507/729 /content/images_dl/491982488816639.jpg: 960x1280 (no detections), 34.8ms
# image 508/729 /content/images_dl/492149871979761.jpg: 960x1280 (no detections), 35.8ms
# image 509/729 /content/images_dl/4921967037818993.jpg: 960x1280 (no detections), 36.5ms
# image 510/729 /content/images_dl/493249118586149.jpg: 960x1280 2 Graffitis, 36.3ms
# image 511/729 /content/images_dl/493444215112084.jpg: 960x1280 2 Graffitis, 35.1ms
# image 512/729 /content/images_dl/494401181746889.jpg: 960x1280 (no detections), 34.8ms
# image 513/729 /content/images_dl/494405895342372.jpg: 960x1280 (no detections), 35.6ms
# image 514/729 /content/images_dl/494765248506441.jpg: 960x1280 (no detections), 36.2ms
# image 515/729 /content/images_dl/496089688485206.jpg: 960x1280 1 Graffiti, 36.1ms
# image 516/729 /content/images_dl/496459818473066.jpg: 960x1280 (no detections), 35.5ms
# image 517/729 /content/images_dl/498942511259186.jpg: 960x1280 2 Graffitis, 35.6ms
# image 518/729 /content/images_dl/499671974506421.jpg: 960x1280 (no detections), 34.8ms
# image 519/729 /content/images_dl/500811807627527.jpg: 960x1280 4 Graffitis, 35.6ms
# image 520/729 /content/images_dl/5013827015300818.jpg: 960x1280 5 Graffitis, 35.3ms
# image 521/729 /content/images_dl/501895974180901.jpg: 960x1280 (no detections), 36.1ms
# image 522/729 /content/images_dl/502285127792877.jpg: 960x1280 (no detections), 36.3ms
# image 523/729 /content/images_dl/504319877411857.jpg: 960x1280 5 Graffitis, 36.2ms
# image 524/729 /content/images_dl/504822243885760.jpg: 960x1280 5 Graffitis, 36.6ms
# image 525/729 /content/images_dl/505024720846392.jpg: 960x1280 (no detections), 35.6ms
# image 526/729 /content/images_dl/505307443809166.jpg: 960x1280 (no detections), 37.4ms
# image 527/729 /content/images_dl/505850467258502.jpg: 960x1280 (no detections), 37.7ms
# image 528/729 /content/images_dl/509314206754965.jpg: 960x1280 1 Graffiti, 36.6ms
# image 529/729 /content/images_dl/509528100085424.jpg: 960x1280 2 Graffitis, 36.0ms
# image 530/729 /content/images_dl/511077426940201.jpg: 960x1280 3 Graffitis, 36.4ms
# image 531/729 /content/images_dl/511093583380765.jpg: 960x1280 1 Graffiti, 37.1ms
# image 532/729 /content/images_dl/512072819801824.jpg: 960x1280 4 Graffitis, 36.6ms
# image 533/729 /content/images_dl/512576613456736.jpg: 960x1280 2 Graffitis, 36.2ms
# image 534/729 /content/images_dl/513760019985979.jpg: 960x1280 (no detections), 36.2ms
# image 535/729 /content/images_dl/513770659995616.jpg: 960x1280 (no detections), 36.5ms
# image 536/729 /content/images_dl/513881329747558.jpg: 960x1280 (no detections), 37.1ms
# image 537/729 /content/images_dl/515173469480312.jpg: 960x1280 (no detections), 36.7ms
# image 538/729 /content/images_dl/516106563102202.jpg: 960x1280 1 Graffiti, 36.7ms
# image 539/729 /content/images_dl/516108032755181.jpg: 960x1280 2 Graffitis, 36.0ms
# image 540/729 /content/images_dl/517407246333772.jpg: 960x1280 (no detections), 36.0ms
# image 541/729 /content/images_dl/518211425883143.jpg: 960x1280 (no detections), 36.6ms
# image 542/729 /content/images_dl/519048192454215.jpg: 960x1280 4 Graffitis, 36.6ms
# image 543/729 /content/images_dl/519237662437154.jpg: 960x1280 3 Graffitis, 36.4ms
# image 544/729 /content/images_dl/519520122382721.jpg: 960x1280 (no detections), 35.5ms
# image 545/729 /content/images_dl/520083362486506.jpg: 960x1280 (no detections), 36.5ms
# image 546/729 /content/images_dl/520845485574668.jpg: 960x1280 1 Graffiti, 35.2ms
# image 547/729 /content/images_dl/521201825705261.jpg: 960x1280 4 Graffitis, 36.5ms
# image 548/729 /content/images_dl/521309142227042.jpg: 960x1280 (no detections), 35.6ms
# image 549/729 /content/images_dl/521829265513949.jpg: 960x1280 (no detections), 37.2ms
# image 550/729 /content/images_dl/522025555625717.jpg: 960x1280 (no detections), 36.2ms
# image 551/729 /content/images_dl/522548835591549.jpg: 960x1280 1 Graffiti, 36.3ms
# image 552/729 /content/images_dl/523341452172885.jpg: 960x1280 (no detections), 36.7ms
# image 553/729 /content/images_dl/525098471828203.jpg: 960x1280 2 Graffitis, 37.2ms
# image 554/729 /content/images_dl/525229115161955.jpg: 960x1280 2 Graffitis, 36.5ms
# image 555/729 /content/images_dl/526247705040298.jpg: 960x1280 1 Graffiti, 36.9ms
# image 556/729 /content/images_dl/526263085198500.jpg: 960x1280 (no detections), 36.4ms
# image 557/729 /content/images_dl/526492078348909.jpg: 960x1280 2 Graffitis, 37.0ms
# image 558/729 /content/images_dl/528658041487257.jpg: 960x1280 (no detections), 37.0ms
# image 559/729 /content/images_dl/529600998045531.jpg: 960x1280 (no detections), 36.9ms
# image 560/729 /content/images_dl/530897534714932.jpg: 960x1280 (no detections), 37.7ms
# image 561/729 /content/images_dl/531471994537201.jpg: 960x1280 (no detections), 36.7ms
# image 562/729 /content/images_dl/532620467730040.jpg: 960x1280 (no detections), 36.3ms
# image 563/729 /content/images_dl/533196067841053.jpg: 960x1280 (no detections), 35.7ms
# image 564/729 /content/images_dl/533636654712647.jpg: 960x1280 (no detections), 36.8ms
# image 565/729 /content/images_dl/533726590950891.jpg: 960x1280 (no detections), 36.5ms
# image 566/729 /content/images_dl/5348508745219296.jpg: 960x1280 (no detections), 37.6ms
# image 567/729 /content/images_dl/5361274040612366.jpg: 960x1280 (no detections), 36.9ms
# image 568/729 /content/images_dl/536948014380759.jpg: 960x1280 (no detections), 36.6ms
# image 569/729 /content/images_dl/5409216249149218.jpg: 960x1280 (no detections), 36.9ms
# image 570/729 /content/images_dl/546123866354417.jpg: 960x1280 1 Graffiti, 37.4ms
# image 571/729 /content/images_dl/546715269652784.jpg: 960x1280 1 Graffiti, 36.8ms
# image 572/729 /content/images_dl/548381616546860.jpg: 960x1280 2 Graffitis, 36.6ms
# image 573/729 /content/images_dl/548915452760453.jpg: 960x1280 (no detections), 36.1ms
# image 574/729 /content/images_dl/549955756001689.jpg: 960x1280 1 Graffiti, 37.3ms
# image 575/729 /content/images_dl/558187446004746.jpg: 960x1280 1 Graffiti, 36.8ms
# image 576/729 /content/images_dl/558828243109764.jpg: 960x1280 (no detections), 36.6ms
# image 577/729 /content/images_dl/561372601492879.jpg: 960x1280 3 Graffitis, 36.4ms
# image 578/729 /content/images_dl/565138581544531.jpg: 960x1280 2 Graffitis, 36.2ms
# image 579/729 /content/images_dl/566966404279500.jpg: 960x1280 (no detections), 35.8ms
# image 580/729 /content/images_dl/5681857441832275.jpg: 960x1280 (no detections), 36.3ms
# image 581/729 /content/images_dl/570821210523501.jpg: 960x1280 (no detections), 36.3ms
# image 582/729 /content/images_dl/570989103869927.jpg: 960x1280 (no detections), 36.1ms
# image 583/729 /content/images_dl/572528381125550.jpg: 960x1280 5 Graffitis, 36.2ms
# image 584/729 /content/images_dl/572964406988408.jpg: 960x1280 6 Graffitis, 36.0ms
# image 585/729 /content/images_dl/573878273623769.jpg: 960x1280 (no detections), 35.4ms
# image 586/729 /content/images_dl/581090449532697.jpg: 960x1280 (no detections), 37.0ms
# image 587/729 /content/images_dl/583784132539239.jpg: 960x1280 2 Graffitis, 36.6ms
# image 588/729 /content/images_dl/591198228507740.jpg: 960x1280 (no detections), 36.4ms
# image 589/729 /content/images_dl/593646758697057.jpg: 960x1280 (no detections), 36.0ms
# image 590/729 /content/images_dl/594998178856085.jpg: 960x1280 1 Graffiti, 36.3ms
# image 591/729 /content/images_dl/601682054104201.jpg: 960x1280 1 Graffiti, 36.6ms
# image 592/729 /content/images_dl/606128323636857.jpg: 960x1280 1 Graffiti, 37.7ms
# image 593/729 /content/images_dl/610202103709559.jpg: 960x1280 9 Graffitis, 37.3ms
# image 594/729 /content/images_dl/613111544117844.jpg: 960x1280 3 Graffitis, 36.6ms
# image 595/729 /content/images_dl/615022292744592.jpg: 960x1280 2 Graffitis, 37.3ms
# image 596/729 /content/images_dl/6186899201427665.jpg: 960x1280 (no detections), 37.5ms
# image 597/729 /content/images_dl/626377938895499.jpg: 960x1280 (no detections), 37.5ms
# image 598/729 /content/images_dl/640484144861267.jpg: 960x1280 (no detections), 36.8ms
# image 599/729 /content/images_dl/646596740670397.jpg: 960x1280 1 Graffiti, 37.6ms
# image 600/729 /content/images_dl/652757880132994.jpg: 960x1280 1 Graffiti, 35.9ms
# image 601/729 /content/images_dl/652885776181991.jpg: 960x1280 (no detections), 36.7ms
# image 602/729 /content/images_dl/6532452616775334.jpg: 960x1280 6 Graffitis, 36.8ms
# image 603/729 /content/images_dl/657980509871785.jpg: 960x1280 4 Graffitis, 36.2ms
# image 604/729 /content/images_dl/724644444870077.jpg: 960x1280 (no detections), 36.4ms
# image 605/729 /content/images_dl/729726508923791.jpg: 960x1280 (no detections), 37.3ms
# image 606/729 /content/images_dl/733335947363205.jpg: 960x1280 (no detections), 37.4ms
# image 607/729 /content/images_dl/735074460523223.jpg: 960x1280 1 Graffiti, 36.6ms
# image 608/729 /content/images_dl/737388040263818.jpg: 960x1280 (no detections), 36.4ms
# image 609/729 /content/images_dl/745991499417829.jpg: 960x1280 (no detections), 35.9ms
# image 610/729 /content/images_dl/746223856836485.jpg: 960x1280 (no detections), 36.7ms
# image 611/729 /content/images_dl/746366842696276.jpg: 960x1280 (no detections), 36.1ms
# image 612/729 /content/images_dl/748890242431704.jpg: 960x1280 (no detections), 36.0ms
# image 613/729 /content/images_dl/749447125637274.jpg: 960x1280 (no detections), 36.8ms
# image 614/729 /content/images_dl/752661855432754.jpg: 960x1280 (no detections), 37.2ms
# image 615/729 /content/images_dl/753780458620545.jpg: 960x1280 (no detections), 36.4ms
# image 616/729 /content/images_dl/753977088811863.jpg: 736x1280 (no detections), 29.7ms
# image 617/729 /content/images_dl/758045824906996.jpg: 960x1280 (no detections), 36.1ms
# image 618/729 /content/images_dl/758957991655155.jpg: 960x1280 2 Graffitis, 36.2ms
# image 619/729 /content/images_dl/762055387676494.jpg: 960x1280 (no detections), 36.2ms
# image 620/729 /content/images_dl/762328111311300.jpg: 960x1280 2 Graffitis, 36.8ms
# image 621/729 /content/images_dl/762376374464466.jpg: 960x1280 (no detections), 36.5ms
# image 622/729 /content/images_dl/763019501245073.jpg: 960x1280 4 Graffitis, 37.2ms
# image 623/729 /content/images_dl/765499330825862.jpg: 960x1280 8 Graffitis, 36.1ms
# image 624/729 /content/images_dl/771086786938024.jpg: 960x1280 (no detections), 36.0ms
# image 625/729 /content/images_dl/772171843502822.jpg: 960x1280 1 Graffiti, 37.0ms
# image 626/729 /content/images_dl/772686870100028.jpg: 960x1280 (no detections), 36.0ms
# image 627/729 /content/images_dl/772887410060939.jpg: 960x1280 1 Graffiti, 36.5ms
# image 628/729 /content/images_dl/774346760390655.jpg: 960x1280 2 Graffitis, 36.6ms
# image 629/729 /content/images_dl/777301994020804.jpg: 960x1280 7 Graffitis, 36.9ms
# image 630/729 /content/images_dl/782886226958801.jpg: 960x1280 1 Graffiti, 37.2ms
# image 631/729 /content/images_dl/783515619238372.jpg: 960x1280 1 Graffiti, 37.0ms
# image 632/729 /content/images_dl/785095798807819.jpg: 960x1280 2 Graffitis, 37.8ms
# image 633/729 /content/images_dl/785452222401639.jpg: 960x1280 (no detections), 36.7ms
# image 634/729 /content/images_dl/786897688887993.jpg: 960x1280 (no detections), 37.1ms
# image 635/729 /content/images_dl/788290461844845.jpg: 960x1280 (no detections), 37.4ms
# image 636/729 /content/images_dl/795698717737523.jpg: 960x1280 (no detections), 36.3ms
# image 637/729 /content/images_dl/798148864420736.jpg: 960x1280 1 Graffiti, 37.3ms
# image 638/729 /content/images_dl/798579324381670.jpg: 960x1280 (no detections), 38.0ms
# image 639/729 /content/images_dl/799606597354609.jpg: 960x1280 1 Graffiti, 38.8ms
# image 640/729 /content/images_dl/802018930435063.jpg: 960x1280 1 Graffiti, 36.3ms
# image 641/729 /content/images_dl/804817110146415.jpg: 960x1280 (no detections), 36.0ms
# image 642/729 /content/images_dl/805054110397734.jpg: 960x1280 (no detections), 37.6ms
# image 643/729 /content/images_dl/807754850145706.jpg: 960x1280 (no detections), 37.7ms
# image 644/729 /content/images_dl/809923439938679.jpg: 960x1280 1 Graffiti, 36.8ms
# image 645/729 /content/images_dl/809991856278994.jpg: 960x1280 (no detections), 36.3ms
# image 646/729 /content/images_dl/810123153267100.jpg: 960x1280 (no detections), 37.1ms
# image 647/729 /content/images_dl/810415086239877.jpg: 960x1280 (no detections), 36.1ms
# image 648/729 /content/images_dl/812034469716778.jpg: 960x1280 2 Graffitis, 36.7ms
# image 649/729 /content/images_dl/812091146411196.jpg: 960x1280 (no detections), 36.0ms
# image 650/729 /content/images_dl/812108573046464.jpg: 960x1280 6 Graffitis, 35.8ms
# image 651/729 /content/images_dl/813395582609305.jpg: 960x1280 (no detections), 36.1ms
# image 652/729 /content/images_dl/816650505937102.jpg: 960x1280 (no detections), 37.8ms
# image 653/729 /content/images_dl/817920412472087.jpg: 960x1280 (no detections), 37.1ms
# image 654/729 /content/images_dl/819113022142459.jpg: 960x1280 (no detections), 37.1ms
# image 655/729 /content/images_dl/819408085597725.jpg: 960x1280 1 Graffiti, 36.7ms
# image 656/729 /content/images_dl/821176465419765.jpg: 960x1280 (no detections), 36.5ms
# image 657/729 /content/images_dl/821223045411691.jpg: 960x1280 (no detections), 36.4ms
# image 658/729 /content/images_dl/824806725058763.jpg: 960x1280 1 Graffiti, 36.7ms
# image 659/729 /content/images_dl/827504464639901.jpg: 960x1280 (no detections), 37.0ms
# image 660/729 /content/images_dl/829259137943013.jpg: 960x1280 1 Graffiti, 38.0ms
# image 661/729 /content/images_dl/829287141271153.jpg: 960x1280 (no detections), 36.9ms
# image 662/729 /content/images_dl/831231784477265.jpg: 960x1280 (no detections), 36.7ms
# image 663/729 /content/images_dl/837004940497141.jpg: 960x1280 (no detections), 37.0ms
# image 664/729 /content/images_dl/839115516699642.jpg: 960x1280 (no detections), 36.5ms
# image 665/729 /content/images_dl/840206666850778.jpg: 960x1280 (no detections), 37.0ms
# image 666/729 /content/images_dl/841225043444863.jpg: 960x1280 (no detections), 36.3ms
# image 667/729 /content/images_dl/841941339751601.jpg: 960x1280 (no detections), 36.0ms
# image 668/729 /content/images_dl/845550686315315.jpg: 736x1280 1 Graffiti, 29.9ms
# image 669/729 /content/images_dl/846415102886583.jpg: 960x1280 (no detections), 35.5ms
# image 670/729 /content/images_dl/848415209047707.jpg: 960x1280 (no detections), 36.8ms
# image 671/729 /content/images_dl/848662535862317.jpg: 960x1280 (no detections), 36.4ms
# image 672/729 /content/images_dl/850101042515806.jpg: 960x1280 (no detections), 36.3ms
# image 673/729 /content/images_dl/867019370515390.jpg: 960x1280 1 Graffiti, 37.2ms
# image 674/729 /content/images_dl/872340026686398.jpg: 960x1280 1 Graffiti, 36.4ms
# image 675/729 /content/images_dl/874810209733865.jpg: 960x1280 (no detections), 36.2ms
# image 676/729 /content/images_dl/875449223042598.jpg: 960x1280 4 Graffitis, 36.6ms
# image 677/729 /content/images_dl/876836286198300.jpg: 960x1280 (no detections), 36.2ms
# image 678/729 /content/images_dl/892173534897091.jpg: 960x1280 (no detections), 37.5ms
# image 679/729 /content/images_dl/894104075398078.jpg: 960x1280 1 Graffiti, 36.7ms
# image 680/729 /content/images_dl/898186861025052.jpg: 960x1280 1 Graffiti, 36.3ms
# image 681/729 /content/images_dl/900373457410716.jpg: 960x1280 2 Graffitis, 36.3ms
# image 682/729 /content/images_dl/902691394792231.jpg: 960x1280 (no detections), 36.4ms
# image 683/729 /content/images_dl/903367597809631.jpg: 960x1280 1 Graffiti, 36.8ms
# image 684/729 /content/images_dl/903390403538017.jpg: 960x1280 (no detections), 36.8ms
# image 685/729 /content/images_dl/906633389899337.jpg: 960x1280 (no detections), 35.9ms
# image 686/729 /content/images_dl/907595106472783.jpg: 960x1280 (no detections), 37.0ms
# image 687/729 /content/images_dl/908524339715637.jpg: 960x1280 3 Graffitis, 37.0ms
# image 688/729 /content/images_dl/908720819967845.jpg: 960x1280 6 Graffitis, 36.3ms
# image 689/729 /content/images_dl/910307356183016.jpg: 960x1280 1 Graffiti, 41.4ms
# image 690/729 /content/images_dl/911373529409574.jpg: 960x1280 (no detections), 34.7ms
# image 691/729 /content/images_dl/912244659345307.jpg: 960x1280 (no detections), 36.1ms
# image 692/729 /content/images_dl/915318652593515.jpg: 960x1280 2 Graffitis, 36.3ms
# image 693/729 /content/images_dl/915577765841392.jpg: 960x1280 1 Graffiti, 35.0ms
# image 694/729 /content/images_dl/918291218723071.jpg: 960x1280 (no detections), 35.8ms
# image 695/729 /content/images_dl/919119335568742.jpg: 960x1280 (no detections), 35.9ms
# image 696/729 /content/images_dl/919503515498563.jpg: 960x1280 1 Graffiti, 36.0ms
# image 697/729 /content/images_dl/920120582107221.jpg: 960x1280 1 Graffiti, 34.8ms
# image 698/729 /content/images_dl/921665405337502.jpg: 960x1280 (no detections), 36.1ms
# image 699/729 /content/images_dl/923193231867639.jpg: 960x1280 1 Graffiti, 36.3ms
# image 700/729 /content/images_dl/924579594777097.jpg: 960x1280 (no detections), 34.8ms
# image 701/729 /content/images_dl/926354895113470.jpg: 960x1280 (no detections), 36.1ms
# image 702/729 /content/images_dl/927438594718093.jpg: 960x1280 (no detections), 36.2ms
# image 703/729 /content/images_dl/928032547973617.jpg: 960x1280 (no detections), 36.4ms
# image 704/729 /content/images_dl/930600094439770.jpg: 960x1280 3 Graffitis, 35.6ms
# image 705/729 /content/images_dl/935282840580987.jpg: 960x1280 (no detections), 35.6ms
# image 706/729 /content/images_dl/936546366889381.jpg: 960x1280 3 Graffitis, 35.6ms
# image 707/729 /content/images_dl/937122627036247.jpg: 960x1280 (no detections), 36.8ms
# image 708/729 /content/images_dl/937235097025000.jpg: 960x1280 (no detections), 35.7ms
# image 709/729 /content/images_dl/938744580253575.jpg: 960x1280 5 Graffitis, 36.8ms
# image 710/729 /content/images_dl/943196833094004.jpg: 960x1280 5 Graffitis, 35.2ms
# image 711/729 /content/images_dl/944756883310514.jpg: 960x1280 (no detections), 35.8ms
# image 712/729 /content/images_dl/946154942835442.jpg: 960x1280 2 Graffitis, 36.4ms
# image 713/729 /content/images_dl/947541519837467.jpg: 960x1280 (no detections), 35.3ms
# image 714/729 /content/images_dl/948107665937913.jpg: 960x1280 1 Graffiti, 36.0ms
# image 715/729 /content/images_dl/951848062295230.jpg: 960x1280 1 Graffiti, 35.6ms
# image 716/729 /content/images_dl/952229542199049.jpg: 960x1280 2 Graffitis, 35.5ms
# image 717/729 /content/images_dl/952422635300598.jpg: 960x1280 1 Graffiti, 35.6ms
# image 718/729 /content/images_dl/957999024951341.jpg: 960x1280 2 Graffitis, 36.0ms
# image 719/729 /content/images_dl/963103338228219.jpg: 960x1280 1 Graffiti, 35.5ms
# image 720/729 /content/images_dl/964319411039615.jpg: 960x1280 1 Graffiti, 35.3ms
# image 721/729 /content/images_dl/965310474270466.jpg: 960x1280 (no detections), 35.4ms
# image 722/729 /content/images_dl/970340920376060.jpg: 960x1280 1 Graffiti, 35.9ms
# image 723/729 /content/images_dl/971614693612593.jpg: 960x1280 (no detections), 35.5ms
# image 724/729 /content/images_dl/972365266902165.jpg: 960x1280 2 Graffitis, 35.2ms
# image 725/729 /content/images_dl/975236356618867.jpg: 960x1280 1 Graffiti, 35.9ms
# image 726/729 /content/images_dl/977225933085555.jpg: 960x1280 (no detections), 35.9ms
# image 727/729 /content/images_dl/981502242617033.jpg: 960x1280 (no detections), 35.0ms
# image 728/729 /content/images_dl/985895395485955.jpg: 960x1280 1 Graffiti, 35.9ms
# image 729/729 /content/images_dl/995068141032346.jpg: 960x1280 (no detections), 35.9ms
# Speed: 1.1ms pre-process, 36.1ms inference, 1.1ms NMS per image at shape (1, 3, 1280, 1280)
# Results saved to runs/graffiti_cli/exp
# 310 labels saved to runs/graffiti_cli/exp/labels
# ============================================================
#
# ✓ Detection finished successfully.

# %% [markdown]
# ## Schritt 7: Detektionsergebnisse parsen
#
# Die Label-Dateien (`labels/*.txt`) im YOLO-Format werden eingelesen und ausgewertet. Für jedes Bild wird gespeichert, ob Graffiti gefunden wurde (`has_graffiti`) und wo sich die Detektionen befinden (`results_by_id`).

# %%
# -------------------------
# 7) Ausgaben von detect.py parsen (inkl. BBox-Koordinaten)
# -------------------------
import os
import glob

labels_dir = os.path.join("runs", "graffiti_cli", "exp", "labels")
results_by_id = {}
has_graffiti = {}

# Optional: Nur bestimmte Klassen-IDs als Graffiti werten (z.B. {0})
# None = alle Klassen zählen als Graffiti
GRAFFITI_CLASS_IDS = None

# Alle heruntergeladenen Bilder initialisieren
for item in dl_items:
    img_id = item["id"]
    results_by_id[img_id] = []
    has_graffiti[img_id] = False

# Label-Dateien parsen
if os.path.isdir(labels_dir):
    for txt in glob.glob(os.path.join(labels_dir, "*.txt")):
        base = os.path.basename(txt)
        img_stem = os.path.splitext(base)[0]  # Dateiname ohne Endung = Image-ID
        img_id = img_stem
        dets = []

        with open(txt, "r") as f:
            for line in f:
                parts = line.strip().split()
                # YOLO-Format: cls cx cy w h conf
                if len(parts) < 6:
                    continue

                cls_id = int(float(parts[0]))
                cx = float(parts[1])
                cy = float(parts[2])
                bw = float(parts[3])
                bh = float(parts[4])
                conf = float(parts[5])

                dets.append({
                    "cls": cls_id,
                    "label": str(cls_id),
                    "conf": conf,
                    "cx": cx,
                    "cy": cy,
                    "w": bw,
                    "h": bh,
                })

                # Prüfen, ob diese Klasse als Graffiti zählt
                if GRAFFITI_CLASS_IDS is None or cls_id in GRAFFITI_CLASS_IDS:
                    has_graffiti[img_id] = True

        results_by_id[img_id] = dets

    graffiti_count = sum(1 for v in has_graffiti.values() if v)
    print(f"✓ Parsing fertig: {graffiti_count} Bilder mit Graffiti gefunden")
    print(f"  Gesamt: {len(dl_items)} Bilder analysiert")
else:
    print(f"⚠ Labels-Verzeichnis fehlt: {labels_dir}")
    print("  Bitte zuerst die CLI-Detektion ausführen.")
# Out:
# ✓ Parsing fertig: 310 Bilder mit Graffiti gefunden
#   Gesamt: 729 Bilder analysiert

# %% [markdown]
# ## Schritt 8: Karten-Assets vorbereiten (Kompression)
#
# Um die HTML-Dateigröße zu reduzieren, werden alle Bilder komprimiert (auf max. 400px Breite, JPEG-Qualität 70%). Dies beschleunigt das Laden der interaktiven Karte erheblich.

# %%
# -------------------------
# 8) Karten-Assets lokal vorbereiten mit Kompression
# -------------------------
import os
import requests
from PIL import Image

def prepare_map_assets(items, out_dir="map_assets", max_width=400, quality=70):
    """
    Bereitet komprimierte Bilder für die Karte vor.
    """
    os.makedirs(out_dir, exist_ok=True)

    for item in items:
        img_id = item.get("id")
        if not img_id:
            continue

        basename = os.path.basename(item.get("path", f"{img_id}.jpg"))
        ext = os.path.splitext(basename)[1] or ".jpg"
        annot_rel = os.path.join("runs", "graffiti_cli", "exp", basename)
        target_path = os.path.join(out_dir, f"{img_id}{ext}")

        try:
            # Priorisiere annotiertes Bild, falls vorhanden
            if os.path.exists(annot_rel):
                src_img = annot_rel
            else:
                url = item.get("remote_url")
                if not url:
                    continue
                r = requests.get(url, timeout=60)
                if r.status_code != 200:
                    continue
                tmp = os.path.join(out_dir, f"_tmp_{img_id}{ext}")
                with open(tmp, "wb") as f:
                    f.write(r.content)
                src_img = tmp

            # Bild komprimieren
            with Image.open(src_img) as im:
                w, h = im.size
                if w > max_width:
                    new_h = int(h * max_width / w)
                    im = im.resize((max_width, new_h), Image.LANCZOS)
                im = im.convert("RGB")
                im.save(target_path, "JPEG", quality=quality, optimize=True)

            item["asset_path"] = target_path
        except Exception:
            continue

    return out_dir

assets_dir = prepare_map_assets(dl_items, max_width=400, quality=70)
print(f"✓ Lokale Karten-Assets vorbereitet (komprimiert): {assets_dir}")
# Out:
# ✓ Lokale Karten-Assets vorbereitet (komprimiert): map_assets

# %% [markdown]
# ## Schritt 9: Interaktive Karte erstellen
#
# Die finale Karte wird mit Folium erstellt:
# - **Rote Marker**: Bilder mit Graffiti-Detektionen
# - **Grüne Marker**: Bilder ohne Graffiti
# - **Popups**: Zeigen das annotierte Bild mit eingezeichneten Bounding Boxes
#
# Die Karte wird als `mainz_graffiti_karte.html` gespeichert und kann im Browser geöffnet werden.

# %%
# -------------------------
# Interaktive Karte (ein Symbol: Punkt + Keil, klickbar, Hover-Hervorhebung)
# Verwendet ausschließlich komprimierte Assets aus assets_dir
# -------------------------
import os
import math
import base64
import folium
from folium import Element
from IPython.display import display, HTML


# ---------- Popup: nur Bild + Text (keine Boxen) ----------
def build_overlay_html(img_path, img_id, dets, use_base64=True):
    """
    Popup nutzt ausschließlich lokale, komprimierte Bilder aus assets_dir.
    """
    if not img_path or not os.path.exists(img_path):
        return (
            "<div style='width:220px;'>"
            f"<b>ID:</b> {img_id}<br>"
            "<span style='color:#b00;'>Kein Asset in assets_dir gefunden.</span>"
            "</div>"
        )

    img_display = img_path
    if use_base64:
        try:
            with open(img_path, "rb") as f:
                img_b64 = base64.b64encode(f.read()).decode("utf-8")
            img_display = f"data:image/jpeg;base64,{img_b64}"
        except Exception:
            img_display = img_path

    det_lines = []
    for d in (dets or [])[:10]:
        if d.get("label") and d.get("conf") is not None:
            try:
                det_lines.append(f"{d['label']} ({float(d['conf']):.2f})")
            except Exception:
                det_lines.append(f"{d['label']}")

    html = "<div style='width:260px;'>"
    html += (
        "<div style='width:240px;height:240px;'>"
        f"<img src='{img_display}' "
        "style='width:240px;height:240px;object-fit:contain;"
        "border-radius:6px;display:block;'>"
        "</div>"
    )
    html += f"<div style='font-size:12px;margin-top:6px;'><b>ID:</b> {img_id}</div>"

    if det_lines:
        html += (
            "<div style='font-size:12px;margin-top:6px;'>"
            "<b>Detektionen:</b><br>"
            + "<br>".join(det_lines)
            + "</div>"
        )

    html += "</div>"
    return html


# ---------- Kombiniertes Symbol: Punkt + Keil ----------
def make_point_wedge_icon(heading_deg, color="#43A047",
                          dot_r=5, wedge_len=22, half_angle_deg=18):
    if heading_deg is None:
        heading_deg = 0.0

    dot_r = float(dot_r)
    L = float(wedge_len)
    a = math.radians(float(half_angle_deg))

    x1 = math.sin(a) * L
    y1 = -math.cos(a) * L
    x2 = -math.sin(a) * L
    y2 = -math.cos(a) * L

    pad = 6.0
    min_x = min(x1, x2, 0.0, -dot_r) - pad
    max_x = max(x1, x2, 0.0,  dot_r) + pad
    min_y = min(y1, y2, 0.0, -dot_r) - pad
    max_y = max(y1, y2, 0.0,  dot_r) + pad

    width = max_x - min_x
    height = max_y - min_y

    cx = -min_x
    cy = -min_y

    html = f"""
    <div class="pw-wrap" style="
        width:{width:.1f}px;
        height:{height:.1f}px;
        transform: rotate({float(heading_deg):.1f}deg);
        transform-origin: {cx:.1f}px {cy:.1f}px;
        pointer-events:auto;
    ">
      <svg width="{width:.1f}" height="{height:.1f}"
           style="display:block;pointer-events:none;">
        <polygon points="{cx:.1f},{cy:.1f}
                         {cx + x1:.1f},{cy + y1:.1f}
                         {cx + x2:.1f},{cy + y2:.1f}"
                 fill="{color}" fill-opacity="0.35"
                 stroke="{color}" stroke-width="2"/>
        <circle cx="{cx:.1f}" cy="{cy:.1f}" r="{dot_r:.1f}"
                fill="{color}" fill-opacity="0.95"
                stroke="{color}" stroke-width="2"/>
      </svg>
    </div>
    """

    return folium.DivIcon(
        html=html,
        icon_size=(width, height),
        icon_anchor=(cx, cy)
    )


# ---------- Karte ----------
m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=18,
    max_zoom=20
)

layer = folium.FeatureGroup(name="Aufnahmen").add_to(m)
marker_names = []
HOVER_SCALE = 1.45

skipped = 0

for item in dl_items:
    # --- Koordinaten ---
    if item.get("lat") is None or item.get("lon") is None:
        continue
    try:
        lat = float(item["lat"])
        lon = float(item["lon"])
    except Exception:
        continue

    img_id = item.get("id", "")
    heading = item.get("heading")

    # --- NUR assets_dir ---
    asset_path = item.get("asset_path")
    if not asset_path or not asset_path.startswith(assets_dir) or not os.path.exists(asset_path):
        skipped += 1
        continue

    has_det = bool(has_graffiti.get(img_id))
    color = "#E53935" if has_det else "#43A047"

    dets = results_by_id.get(img_id) or []
    popup_html = build_overlay_html(asset_path, img_id, dets)

    icon = make_point_wedge_icon(
        heading_deg=float(heading) if heading is not None else 0.0,
        color=color
    )

    mk = folium.Marker(
        location=[lat, lon],
        icon=icon,
        tooltip=f"ID: {img_id}",
        popup=folium.Popup(popup_html, max_width=320)
    ).add_to(layer)

    marker_names.append(mk.get_name())

folium.LayerControl().add_to(m)

# ---------- Hover-Vergrößerung ----------
js = ["<script>"]
js.append("""
function _pw_set_scale(el, s){
  if(!el) return;
  el.style.transform = el.style.transform.replace(/ scale\\([^\\)]*\\)/,'');
  el.style.transform += ' scale(' + s + ')';
}
""")

for name in marker_names:
    js.append(f"""
    (function(){{
      var m = {name};
      m.on('add', function(){{
        var el = m.getElement();
        if(!el) return;
        var w = el.querySelector('.pw-wrap');
        if(!w) return;
        el.addEventListener('mouseenter', function(){{ _pw_set_scale(w, {HOVER_SCALE}); }});
        el.addEventListener('mouseleave', function(){{ _pw_set_scale(w, 1.0); }});
      }});
    }})();
    """)

js.append("</script>")
m.get_root().html.add_child(Element("\\n".join(js)))

out_html = project_base_path + "/mainz_graffiti_karte.html"
m.save(out_html)

print(f"Karte gespeichert: {out_html}")
print(f"Übersprungen (kein Asset in {assets_dir}): {skipped}")

display(HTML(m._repr_html_()))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Zusatzaufgabe (Optional): Graffiti auf Gebäudewänden lokalisieren
#
# **Ziel:** Graffiti-Objekte mithilfe von OSM-Gebäudedaten und Triangulation der nächstgelegenen Gebäudewand zuordnen.
#
# **Schritte:**
# 1. OSM-Gebäude in der BBox abrufen (Overpass API)
# 2. Für jeden Graffiti-Punkt die nächstgelegene Gebäudewand berechnen
# 3. Vergleich: Kamerarichtung (Heading) ↔ Wandorientierung
# 4. Statistik: Auf welchen Häusern/Wänden am meisten Graffiti?
#
# **Bonus:** Visualisierung auf der Karte (z. B. Gebäudepolygone mit Farbcodierung nach Graffiti-Dichte).
